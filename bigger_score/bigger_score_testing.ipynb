# %% [markdown]
# # The goal is to create one master Dataframe/CSV with each of these metrics for BiggerScore V1
# - 5-Year Household Formation
# - 5-Year Population Growth
# - 5-Year Job Growth
# - 5-Year Wage Growth
# - Unemployment Rate
# - SFH Units Permitted
# - MF Units Permitted
# - Median Price
# - Median Rent
# - Rent-Price Ratio
# - Average Insurance
# - Median Property Taxes
# - Vacancy Rate
# - 1-Year Appreciation
# - 1-Year Rent Growth
# - Population Size Category
# - Landlord Friendliness

# %%
# Import modules
import pandas as pd
import numpy as np
from numpy import log as ln
from numpy import log10
from numpy_financial import pmt
import os
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta
from pandas.tseries.offsets import MonthEnd
from functools import reduce

# Set up Pandas defaults
pd.options.display.float_format = '{:.4f}'.format
pd.set_option("display.max_columns", None)

# Define helper function to create directory
def create_folder(the_path):
    "Create directory if nonexistent."
    if not os.path.isdir(the_path):
        os.mkdir(the_path)

create_folder('outputs')

census_end_year = int(input("What year was the most recent ACS 5-Year census data pulled from? "))
acs_1_year = int(input("What year was the most recent ACS 1-Year census data pulled from? "))

# %%
def clean_BLS_msa_names(dataframe):
    """
    This functions standardizes the MSA names
    between the BLS dataset and the Zillow
    datasets by only taking the first city
    within a BLS-MSA with a "-" hyphenate, 
    and the first state with a "-" hyphenate.
    
    For example: 'Houston-The Woodlands-Sugar Land, TX'
    will be turned into just 'Houston, TX' and
    'Cincinnati, OH-KY-IN' will be turned into
    just 'Cincinnati, OH'.

    An exception will be made for 'Wildwood-The Villages, FL', 
    which will be reduced to just 'The Villages, FL'.
    """
    
    df = dataframe.copy()
    
    # Get the state column
    df['state'] = df['msa_name'].str.split(',').str[1].str.strip().str.strip("*")
    df['state'] = df['state'].str.split('-').str[0].str.strip()
    
    # Get the first city name
    df['city'] = df['msa_name'].str.split(',').str[0].str.strip()
    df['city'] = df['city'].str.split('-').str[0].str.strip()
    df['city'] = df['city'].str.split('/').str[0].str.strip()

    # Remove 'NECTA' from city name
    df['state'] = df['state'].str.replace(" NECTA", "", regex=False)
    
    # Get msa name
    df['msa_name'] = df['city'] + ", " + df['state']

    ### Create exceptions
    df.loc[df['msa_name']=='Wildwood, FL', 'msa_name'] = 'The Villages, FL'
    
    return df

# %% [markdown]
# ### Get 5-year Household formation for all MSAs

# %%
households = pd.read_csv(
    "../downloaded_datasets/cleaned_census_api_files/standardized/standardized_msa/households_msa_from_county_sum.csv", 
    dtype={'msa_code':str})

households['5-Year Household Growth'] = (households[f'{census_end_year}'] - households[f'{census_end_year - 5}']) / households[f'{census_end_year - 5}']
households['1-Year Household Growth'] = (households[f'{census_end_year}'] - households[f'{census_end_year - 1}']) / households[f'{census_end_year - 1}']


# Only keep certian columns
households = households[['msa_name','msa_code','5-Year Household Growth','1-Year Household Growth']]

# EDA
households.sort_values('5-Year Household Growth', ascending=False)
# Out:
#                              msa_name msa_code  5-Year Household Growth  \
# 58   Austin-Round Rock-San Marcos, TX    12420                   0.2500
# 589                     Nantucket, MA    34880                   0.2388
# 903         Wildwood-The Villages, FL    45540                   0.2281
# 732                    St. George, UT    41100                   0.2246
# 32                        Andrews, TX    11380                   0.2198
# ..                                ...      ...                      ...
# 294                  Forrest City, AR    22620                  -0.1312
# 103                        Borger, TX    14420                  -0.1395
# 545                Middlesborough, KY    33180                  -0.1453
# 506                      Magnolia, AR    31620                  -0.1618
# 134                        Camden, AR    15780                  -0.1755
#
#      1-Year Household Growth
# 58                    0.0501
# 589                   0.1558
# 903                   0.0466
# 732                   0.0452
# 32                    0.0543
# ..                       ...
# 294                  -0.0054
# 103                  -0.0247
# 545                  -0.0028
# 506                   0.0075
# 134                  -0.0207
#
# [928 rows x 4 columns]

# %% [markdown]
# ### Get 5-Year Population Growth for MSAs

# %%
population = pd.read_csv(
    "../downloaded_datasets/cleaned_census_api_files/standardized/standardized_msa/population_msa_from_county_sum.csv", 
    dtype={'msa_code':str})
# population = population[~population['msa_code'].isin(problem_msa_codes)] # Remove problem MSAs
population['5-Year Population Growth'] = (population[f'{census_end_year}'] - population[f'{census_end_year - 5}']) / population[f'{census_end_year - 5}']
population['1-Year Population Growth'] = (population[f'{census_end_year}'] - population[f'{census_end_year - 1}']) / population[f'{census_end_year - 1}']


# Only keep certian columns
population = population[['msa_name','msa_code',f'{census_end_year}',
                         '5-Year Population Growth','1-Year Population Growth']]

# Rename
population.rename(columns={f'{census_end_year}':'Population'}, inplace=True)

# EDA
population.sort_values('5-Year Population Growth', ascending=False).head(20)
# Out:
#                                        msa_name msa_code   Population  \
# 701                                 Rexburg, ID    39940   66006.0000
# 589                               Nantucket, MA    34880   14065.0000
# 412                               Jefferson, GA    27600   77033.0000
# 146                              Cedar City, UT    16260   58068.0000
# 641                                 Pahrump, NV    37220   51698.0000
# 872                          Vineyard Haven, MA    47240   20543.0000
# 107                                 Bozeman, MT    14580  119685.0000
# 905                               Williston, ND    48780   39076.0000
# 732                              St. George, UT    41100  183297.0000
# 336                                 Greeley, CO    24540  331466.0000
# 178                           Coeur d'Alene, ID    17660  173396.0000
# 687                         Provo-Orem-Lehi, UT    39340  677964.0000
# 587  Myrtle Beach-Conway-North Myrtle Beach, SC    34820  356578.0000
# 58             Austin-Round Rock-San Marcos, TX    12420 2296377.0000
# 214                   Daphne-Fairhope-Foley, AL    19300  233420.0000
# 745                               Sandpoint, ID    41760   47976.0000
# 100                              Boise City, ID    14260  771602.0000
# 83                                     Bend, OR    13460  248998.0000
# 903                   Wildwood-The Villages, FL    45540  131832.0000
# 456                   Lakeland-Winter Haven, FL    29460  736229.0000
#
#      5-Year Population Growth  1-Year Population Growth
# 701                    0.2909                    0.0258
# 589                    0.2889                    0.0196
# 412                    0.2064                    0.0433
# 146                    0.1972                    0.0399
# 641                    0.1941                    0.0320
# 872                    0.1892                    0.0131
# 107                    0.1881                    0.0254
# 905                    0.1871                    0.0160
# 732                    0.1782                    0.0383
# 336                    0.1601                    0.0280
# 178                    0.1550                    0.0302
# 687                    0.1546                    0.0274
# 587                    0.1496                    0.0340
# 58                     0.1478                    0.0278
# 214                    0.1478                    0.0277
# 745                    0.1462                    0.0322
# 100                    0.1392                    0.0279
# 83                     0.1331                    0.0226
# 903                    0.1291                    0.0353
# 456                    0.1287                    0.0324

# %% [markdown]
# ### Get Vacancy Rate

# %%
vacancy = pd.read_csv(
    "../downloaded_datasets/cleaned_census_api_files/standardized/standardized_msa/vacancy_rate_msa_from_county_sum.csv", 
    dtype={'msa_code':str})
vacancy.rename(columns={f'{census_end_year}':'Vacancy_Rate'}, inplace=True)
vacancy = vacancy[['msa_name', 'msa_code', 'Vacancy_Rate']]
vacancy
# Out:
#                   msa_name msa_code  Vacancy_Rate
# 0             Aberdeen, SD    10100        0.1166
# 1             Aberdeen, WA    10140        0.1840
# 2              Abilene, TX    10180        0.1270
# 3                  Ada, OK    10220        0.1505
# 4               Adrian, MI    10300        0.1148
# ..                     ...      ...           ...
# 923  Youngstown-Warren, OH    49660        0.0990
# 924          Yuba City, CA    49700        0.0557
# 925               Yuma, AZ    49740        0.1953
# 926         Zanesville, OH    49780        0.0978
# 927             Zapata, TX    49820        0.2593
#
# [928 rows x 3 columns]

# %% [markdown]
# ### Read in Price and Rent from Census ACS 1-Year

# %%
### Read in Price
census_price = pd.read_csv(
    "../downloaded_datasets/cleaned_census_api_files/msa_data/median_price_msa_acs1.csv",
    dtype={'msa_code':str})

census_price['5-Year Price Growth'] = (census_price[f'{acs_1_year}'] - census_price[f'{acs_1_year - 5}']) / census_price[f'{acs_1_year - 5}']

# Only keep certian columns
census_price = census_price[['msa_code',f'{acs_1_year}','5-Year Price Growth']]

# Rename
census_price.rename(columns={f'{acs_1_year}':'ACS_1_Year_Median_Price'}, inplace=True)

# EDA
census_price.sort_values('5-Year Price Growth', ascending=False).head(20)
# Out:
#     msa_code  ACS_1_Year_Median_Price  5-Year Price Growth
# 156    25980              235100.0000               1.0972
# 278    38540              341800.0000               1.0615
# 157    26140              278800.0000               1.0262
# 75     17660              556500.0000               1.0127
# 328    42700              208900.0000               0.9745
# 117    22220              342100.0000               0.9706
# 163    26820              386100.0000               0.8797
# 370    47460              429700.0000               0.8530
# 195    29460              296300.0000               0.8369
# 188    28940              320700.0000               0.8253
# 211    30860              466900.0000               0.8245
# 271    37860              308600.0000               0.8174
# 286    39380              313700.0000               0.8112
# 51     15260              281800.0000               0.8111
# 269    37460              313100.0000               0.7891
# 67     16860              289700.0000               0.7861
# 43     14260              471700.0000               0.7840
# 50     15180              154200.0000               0.7827
# 93     19660              355000.0000               0.7803
# 349    45300              372100.0000               0.7719

# %%
### Read in Rent
census_rent = pd.read_csv(
    "../downloaded_datasets/cleaned_census_api_files/msa_data/median_rent_msa_acs1.csv",
    dtype={'msa_code':str})

census_rent['5-Year Rent Growth'] = (census_rent[f'{acs_1_year}'] - census_rent[f'{acs_1_year - 5}']) / census_rent[f'{acs_1_year - 5}']

# Only keep certian columns
census_rent = census_rent[['msa_code',f'{acs_1_year}','5-Year Rent Growth']]

# Rename
census_rent.rename(columns={f'{acs_1_year}':'ACS_1_Year_Median_Rent'}, inplace=True)

# EDA
census_rent.sort_values('5-Year Rent Growth', ascending=False).head(20)
# Out:
#     msa_code  ACS_1_Year_Median_Rent  5-Year Rent Growth
# 305    41100               1529.0000              0.7257
# 275    38240               1203.0000              0.6896
# 274    38060               1605.0000              0.6806
# 249    34940               1867.0000              0.6420
# 43     14260               1379.0000              0.6320
# 47     14580               1664.0000              0.6266
# 211    30860               1054.0000              0.6067
# 268    37340               1450.0000              0.6022
# 349    45300               1558.0000              0.5979
# 85     18880               1458.0000              0.5952
# 257    36100               1137.0000              0.5947
# 142    24780                847.0000              0.5802
# 162    26620               1062.0000              0.5757
# 259    36260               1364.0000              0.5660
# 65     16740               1353.0000              0.5642
# 278    38540                909.0000              0.5592
# 19     12020               1092.0000              0.5556
# 56     15980               1649.0000              0.5542
# 20     12060               1521.0000              0.5520
# 101    20500               1383.0000              0.5435

# %%
### Merge the two and create a rent-price ratio
census_price_rent = census_price.merge(census_rent, how='inner', on='msa_code')

# Create rent-rpice ratio
census_price_rent['ACS_1_Year_Rent-Price_Ratio'] = 100 * census_price_rent['ACS_1_Year_Median_Rent'] / census_price_rent['ACS_1_Year_Median_Price']

census_price_rent
# Out:
#     msa_code  ACS_1_Year_Median_Price  5-Year Price Growth  \
# 0      10180              180400.0000               0.5096
# 1      10380              136500.0000               0.4368
# 2      10420              216000.0000               0.3891
# 3      10500              164100.0000               0.4665
# 4      10540              398300.0000               0.5663
# ..       ...                      ...                  ...
# 388    49420              318900.0000               0.7099
# 389    49620              257600.0000               0.4077
# 390    49660              149700.0000               0.3051
# 391    49700              398200.0000               0.3498
# 392    49740              246900.0000               0.7560
#
#      ACS_1_Year_Median_Rent  5-Year Rent Growth  ACS_1_Year_Rent-Price_Ratio
# 0                  985.0000              0.3643                       0.5460
# 1                  410.0000              0.2202                       0.3004
# 2                  819.0000              0.2133                       0.3792
# 3                  617.0000              0.1797                       0.3760
# 4                 1181.0000              0.3927                       0.2965
# ..                      ...                 ...                          ...
# 388                933.0000              0.4136                       0.2926
# 389                949.0000              0.2842                       0.3684
# 390                626.0000              0.1636                       0.4182
# 391               1114.0000              0.3619                       0.2798
# 392                878.0000              0.2688                       0.3556
#
# [393 rows x 6 columns]

# %% [markdown]
# ### Read in total units

# %%
# Read in Total Units
total_units = pd.read_csv("../downloaded_datasets/cleaned_census_api_files/standardized/standardized_msa/total_units_msa_from_county_sum.csv",
                          dtype={'msa_code':str})
total_units = total_units[['msa_code',f'{census_end_year}']]
total_units.rename(columns={f'{census_end_year}':'Total_Units'}, inplace=True)
total_units
# Out:
#     msa_code  Total_Units
# 0      10100   19896.0000
# 1      10140   36204.0000
# 2      10180   74540.0000
# 3      10220   17424.0000
# 4      10300   43634.0000
# ..       ...          ...
# 923    49660  202778.0000
# 924    49700   64186.0000
# 925    49740   92808.0000
# 926    49780   38348.0000
# 927    49820    6183.0000
#
# [928 rows x 2 columns]

# %% [markdown]
# ### Merge all census datasets

# %%
census = households.merge(population, how='left', on=['msa_name','msa_code'])
census = census.merge(vacancy, how='left', on=['msa_name', 'msa_code'])
census = census.merge(census_price_rent, how='left', on=['msa_code'])
census = census.merge(total_units, how='left', on=['msa_code'])

# Prep for BLS merge
census['msa_name_original'] = census['msa_name']
census = clean_BLS_msa_names(census)

census
# Out:
#            msa_name msa_code  5-Year Household Growth  \
# 0      Aberdeen, SD    10100                  -0.0184
# 1      Aberdeen, WA    10140                   0.0524
# 2       Abilene, TX    10180                   0.0780
# 3           Ada, OK    10220                   0.0199
# 4        Adrian, MI    10300                   0.0134
# ..              ...      ...                      ...
# 923  Youngstown, OH    49660                  -0.0111
# 924   Yuba City, CA    49700                   0.0437
# 925        Yuma, AZ    49740                   0.0420
# 926  Zanesville, OH    49780                   0.0073
# 927      Zapata, TX    49820                   0.0276
#
#      1-Year Household Growth  Population  5-Year Population Growth  \
# 0                    -0.0063  42292.0000                   -0.0074
# 1                     0.0076  75672.0000                    0.0590
# 2                     0.0116 176656.0000                    0.0453
# 3                     0.0135  38116.0000                   -0.0045
# 4                    -0.0011  99263.0000                    0.0069
# ..                       ...         ...                       ...
# 923                   0.0023 429728.0000                   -0.0126
# 924                   0.0171 180806.0000                    0.0621
# 925                   0.0270 204374.0000                    0.0005
# 926                   0.0185  86393.0000                    0.0054
# 927                   0.0433  13896.0000                   -0.0360
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                     -0.0043        0.1166                      NaN
# 1                      0.0125        0.1840                      NaN
# 2                      0.0081        0.1270              180400.0000
# 3                      0.0004        0.1505                      NaN
# 4                     -0.0008        0.1148                      NaN
# ..                        ...           ...                      ...
# 923                   -0.0035        0.0990              149700.0000
# 924                    0.0074        0.0557              398200.0000
# 925                    0.0070        0.1953              246900.0000
# 926                    0.0005        0.0978                      NaN
# 927                   -0.0035        0.2593                      NaN
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0                    NaN                     NaN                 NaN
# 1                    NaN                     NaN                 NaN
# 2                 0.5096                985.0000              0.3643
# 3                    NaN                     NaN                 NaN
# 4                    NaN                     NaN                 NaN
# ..                   ...                     ...                 ...
# 923               0.3051                626.0000              0.1636
# 924               0.3498               1114.0000              0.3619
# 925               0.7560                878.0000              0.2688
# 926                  NaN                     NaN                 NaN
# 927                  NaN                     NaN                 NaN
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units      msa_name_original state  \
# 0                            NaN   19896.0000           Aberdeen, SD    SD
# 1                            NaN   36204.0000           Aberdeen, WA    WA
# 2                         0.5460   74540.0000            Abilene, TX    TX
# 3                            NaN   17424.0000                Ada, OK    OK
# 4                            NaN   43634.0000             Adrian, MI    MI
# ..                           ...          ...                    ...   ...
# 923                       0.4182  202778.0000  Youngstown-Warren, OH    OH
# 924                       0.2798   64186.0000          Yuba City, CA    CA
# 925                       0.3556   92808.0000               Yuma, AZ    AZ
# 926                          NaN   38348.0000         Zanesville, OH    OH
# 927                          NaN    6183.0000             Zapata, TX    TX
#
#            city
# 0      Aberdeen
# 1      Aberdeen
# 2       Abilene
# 3           Ada
# 4        Adrian
# ..          ...
# 923  Youngstown
# 924   Yuba City
# 925        Yuma
# 926  Zanesville
# 927      Zapata
#
# [928 rows x 17 columns]

# %% [markdown]
# ### Create a cateogry for population size

# %%
census['Population_Size_Category'] = np.where(
    census['Population']<100_000, 1,
    np.where(
        census['Population']<250_000, 2,
        np.where(
            census['Population']<500_000, 3,
            np.where(census['Population']<1_000_000, 4, 5)
        )
    )
)

census
# Out:
#            msa_name msa_code  5-Year Household Growth  \
# 0      Aberdeen, SD    10100                  -0.0184
# 1      Aberdeen, WA    10140                   0.0524
# 2       Abilene, TX    10180                   0.0780
# 3           Ada, OK    10220                   0.0199
# 4        Adrian, MI    10300                   0.0134
# ..              ...      ...                      ...
# 923  Youngstown, OH    49660                  -0.0111
# 924   Yuba City, CA    49700                   0.0437
# 925        Yuma, AZ    49740                   0.0420
# 926  Zanesville, OH    49780                   0.0073
# 927      Zapata, TX    49820                   0.0276
#
#      1-Year Household Growth  Population  5-Year Population Growth  \
# 0                    -0.0063  42292.0000                   -0.0074
# 1                     0.0076  75672.0000                    0.0590
# 2                     0.0116 176656.0000                    0.0453
# 3                     0.0135  38116.0000                   -0.0045
# 4                    -0.0011  99263.0000                    0.0069
# ..                       ...         ...                       ...
# 923                   0.0023 429728.0000                   -0.0126
# 924                   0.0171 180806.0000                    0.0621
# 925                   0.0270 204374.0000                    0.0005
# 926                   0.0185  86393.0000                    0.0054
# 927                   0.0433  13896.0000                   -0.0360
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                     -0.0043        0.1166                      NaN
# 1                      0.0125        0.1840                      NaN
# 2                      0.0081        0.1270              180400.0000
# 3                      0.0004        0.1505                      NaN
# 4                     -0.0008        0.1148                      NaN
# ..                        ...           ...                      ...
# 923                   -0.0035        0.0990              149700.0000
# 924                    0.0074        0.0557              398200.0000
# 925                    0.0070        0.1953              246900.0000
# 926                    0.0005        0.0978                      NaN
# 927                   -0.0035        0.2593                      NaN
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0                    NaN                     NaN                 NaN
# 1                    NaN                     NaN                 NaN
# 2                 0.5096                985.0000              0.3643
# 3                    NaN                     NaN                 NaN
# 4                    NaN                     NaN                 NaN
# ..                   ...                     ...                 ...
# 923               0.3051                626.0000              0.1636
# 924               0.3498               1114.0000              0.3619
# 925               0.7560                878.0000              0.2688
# 926                  NaN                     NaN                 NaN
# 927                  NaN                     NaN                 NaN
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units      msa_name_original state  \
# 0                            NaN   19896.0000           Aberdeen, SD    SD
# 1                            NaN   36204.0000           Aberdeen, WA    WA
# 2                         0.5460   74540.0000            Abilene, TX    TX
# 3                            NaN   17424.0000                Ada, OK    OK
# 4                            NaN   43634.0000             Adrian, MI    MI
# ..                           ...          ...                    ...   ...
# 923                       0.4182  202778.0000  Youngstown-Warren, OH    OH
# 924                       0.2798   64186.0000          Yuba City, CA    CA
# 925                       0.3556   92808.0000               Yuma, AZ    AZ
# 926                          NaN   38348.0000         Zanesville, OH    OH
# 927                          NaN    6183.0000             Zapata, TX    TX
#
#            city  Population_Size_Category
# 0      Aberdeen                         1
# 1      Aberdeen                         1
# 2       Abilene                         2
# 3           Ada                         1
# 4        Adrian                         1
# ..          ...                       ...
# 923  Youngstown                         3
# 924   Yuba City                         2
# 925        Yuma                         2
# 926  Zanesville                         1
# 927      Zapata                         1
#
# [928 rows x 18 columns]

# %% [markdown]
# ### Now read in the BLS metrics

# %%
job_growth = pd.read_csv("../downloaded_datasets/bls_msa_job_growth.csv", dtype={'msa_code':str})

# Get most recent date
job_growth['date'] = pd.to_datetime(job_growth['date'])
most_recent_date = job_growth['date'].max()

# Get date 5 years ago
five_yrs_ago = most_recent_date - pd.DateOffset(years=5)

# Only keep relevant dates
job_growth = job_growth[(job_growth['date']==most_recent_date) |
                        (job_growth['date']==five_yrs_ago) ]

# Sort again
job_growth = job_growth.sort_values(['msa_code','date'], ascending=[True, True])

# Calculate percent change and only keep the most recent date
job_growth['5-Year Job Growth'] = job_growth['value'].pct_change()
job_growth = job_growth[job_growth['date']==most_recent_date]

job_growth = job_growth[['msa_code','msa_name','value','5-Year Job Growth']]

# Rename
job_growth = job_growth.rename(columns={'value':'Jobs'})
job_growth = clean_BLS_msa_names(job_growth)

job_growth.head(10)
# Out:
#      msa_code         msa_name        Jobs  5-Year Job Growth state  \
# 0       10180      Abilene, TX  78200.0000             0.0831    TX
# 128     10380    Aguadilla, PR  59000.0000             0.1546    PR
# 256     10420        Akron, OH 336900.0000            -0.0068    OH
# 384     10500       Albany, GA  63100.0000             0.0064    GA
# 512     10540       Albany, OR  48200.0000             0.0478    OR
# 640     10580       Albany, NY 472100.0000             0.0013    NY
# 768     10740  Albuquerque, NM 423900.0000             0.0627    NM
# 896     10780   Alexandria, LA  61800.0000            -0.0032    LA
# 1024    10900    Allentown, PA 399800.0000             0.0577    PA
# 1152    11020      Altoona, PA  62100.0000             0.0065    PA
#
#              city
# 0         Abilene
# 128     Aguadilla
# 256         Akron
# 384        Albany
# 512        Albany
# 640        Albany
# 768   Albuquerque
# 896    Alexandria
# 1024    Allentown
# 1152      Altoona

# %% [markdown]
# ### Read in Wage Growth

# %%
wage_growth = pd.read_csv("../downloaded_datasets/bls_msa_average_wage.csv", dtype={'msa_code':str})

# Get most recent date
wage_growth['date'] = pd.to_datetime(wage_growth['date'])
most_recent_date = wage_growth['date'].max()

# Get date 5 years ago
five_yrs_ago = most_recent_date - pd.DateOffset(years=5)

# Only keep relevant dates
wage_growth = wage_growth[(wage_growth['date']==most_recent_date) |
                        (wage_growth['date']==five_yrs_ago) ]

# Sort again
wage_growth = wage_growth.sort_values(['msa_code','date'], ascending=[True, True])

# Calculate percent change and only keep the most recent date
wage_growth['5-Year Income Growth'] = wage_growth['value'].pct_change()
wage_growth = wage_growth[wage_growth['date']==most_recent_date]

wage_growth = wage_growth[['msa_code','value','5-Year Income Growth']]

# Rename
wage_growth = wage_growth.rename(columns={'value':'Income'})

wage_growth.sort_values("5-Year Income Growth", ascending=False).head(10)
# Out:
#       msa_code     Income  5-Year Income Growth
# 13666    20940 50214.3200                0.5756
# 42308    43420 55651.4400                0.5678
# 23010    27980 65271.4400                0.5603
# 16738    23540 58091.8000                0.5427
# 22498    27740 53904.2400                0.5226
# 4834     13900 72016.8800                0.5194
# 48580    48900 58167.2000                0.4998
# 11490    19180 59978.8800                0.4853
# 18018    24500 58626.8800                0.4815
# 3682     12980 57369.0000                0.4788

# %% [markdown]
# ### Read in Unemployment

# %%
unemployment = pd.read_csv("../downloaded_datasets/bls_msa_unemployment.csv", dtype={'msa_code':str})

unemployment['date'] = pd.to_datetime(unemployment['date'])
unemployment = unemployment[unemployment['date']==unemployment['date'].max()]

unemployment = unemployment[['msa_code','value']]
unemployment.rename(columns={'value':'Unemployment_Rate'}, inplace=True)
unemployment
# Out:
#       msa_code  Unemployment_Rate
# 0        10180             3.8000
# 128      10380             7.5000
# 256      10420             4.3000
# 384      10500             4.9000
# 512      10540             4.5000
# ...        ...                ...
# 49152    49420             6.2000
# 49280    49620             4.0000
# 49408    49660             5.0000
# 49536    49700             7.3000
# 49664    49740            16.3000
#
# [389 rows x 2 columns]

# %% [markdown]
# ### Merge all BLS data together

# %%
bls_data = job_growth.merge(wage_growth, how='inner', on='msa_code')
bls_data = bls_data.merge(unemployment, how='inner', on='msa_code')
bls_data.drop(columns=['state','city'], inplace=True)
bls_data
# Out:
#     msa_code         msa_name        Jobs  5-Year Job Growth     Income  \
# 0      10180      Abilene, TX  78200.0000             0.0831 53747.7200
# 1      10380    Aguadilla, PR  59000.0000             0.1546 27089.4000
# 2      10420        Akron, OH 336900.0000            -0.0068 58651.8400
# 3      10500       Albany, GA  63100.0000             0.0064 40566.2400
# 4      10540       Albany, OR  48200.0000             0.0478 58515.6000
# ..       ...              ...         ...                ...        ...
# 384    76600   Pittsfield, MA  41000.0000            -0.0398 49026.6400
# 385    76750     Portland, ME 224700.0000             0.0298 57711.6800
# 386    77200   Providence, RI 605700.0000             0.0103 58959.1600
# 387    78100  Springfield, MA 332100.0000            -0.0104 55604.6400
# 388    79600    Worcester, MA 294200.0000             0.0258 54933.8400
#
#      5-Year Income Growth  Unemployment_Rate
# 0                  0.3829             3.8000
# 1                  0.1748             7.5000
# 2                  0.3022             4.3000
# 3                  0.0164             4.9000
# 4                  0.3933             4.5000
# ..                    ...                ...
# 384                0.0749             4.2000
# 385                0.2344             2.2000
# 386                0.2799             5.3000
# 387                0.1018             5.0000
# 388                0.0535             4.5000
#
# [389 rows x 7 columns]

# %% [markdown]
# ### Merge Census data with BLS data

# %%
census_bls = census.merge(bls_data, how='left', on=['msa_name'])
census_bls.rename(columns={
    'msa_code_x':'msa_code_census',
    'msa_code_y':'msa_code_bls'
}, inplace=True)
census_bls
# Out:
#            msa_name msa_code_census  5-Year Household Growth  \
# 0      Aberdeen, SD           10100                  -0.0184
# 1      Aberdeen, WA           10140                   0.0524
# 2       Abilene, TX           10180                   0.0780
# 3           Ada, OK           10220                   0.0199
# 4        Adrian, MI           10300                   0.0134
# ..              ...             ...                      ...
# 923  Youngstown, OH           49660                  -0.0111
# 924   Yuba City, CA           49700                   0.0437
# 925        Yuma, AZ           49740                   0.0420
# 926  Zanesville, OH           49780                   0.0073
# 927      Zapata, TX           49820                   0.0276
#
#      1-Year Household Growth  Population  5-Year Population Growth  \
# 0                    -0.0063  42292.0000                   -0.0074
# 1                     0.0076  75672.0000                    0.0590
# 2                     0.0116 176656.0000                    0.0453
# 3                     0.0135  38116.0000                   -0.0045
# 4                    -0.0011  99263.0000                    0.0069
# ..                       ...         ...                       ...
# 923                   0.0023 429728.0000                   -0.0126
# 924                   0.0171 180806.0000                    0.0621
# 925                   0.0270 204374.0000                    0.0005
# 926                   0.0185  86393.0000                    0.0054
# 927                   0.0433  13896.0000                   -0.0360
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                     -0.0043        0.1166                      NaN
# 1                      0.0125        0.1840                      NaN
# 2                      0.0081        0.1270              180400.0000
# 3                      0.0004        0.1505                      NaN
# 4                     -0.0008        0.1148                      NaN
# ..                        ...           ...                      ...
# 923                   -0.0035        0.0990              149700.0000
# 924                    0.0074        0.0557              398200.0000
# 925                    0.0070        0.1953              246900.0000
# 926                    0.0005        0.0978                      NaN
# 927                   -0.0035        0.2593                      NaN
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0                    NaN                     NaN                 NaN
# 1                    NaN                     NaN                 NaN
# 2                 0.5096                985.0000              0.3643
# 3                    NaN                     NaN                 NaN
# 4                    NaN                     NaN                 NaN
# ..                   ...                     ...                 ...
# 923               0.3051                626.0000              0.1636
# 924               0.3498               1114.0000              0.3619
# 925               0.7560                878.0000              0.2688
# 926                  NaN                     NaN                 NaN
# 927                  NaN                     NaN                 NaN
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units      msa_name_original state  \
# 0                            NaN   19896.0000           Aberdeen, SD    SD
# 1                            NaN   36204.0000           Aberdeen, WA    WA
# 2                         0.5460   74540.0000            Abilene, TX    TX
# 3                            NaN   17424.0000                Ada, OK    OK
# 4                            NaN   43634.0000             Adrian, MI    MI
# ..                           ...          ...                    ...   ...
# 923                       0.4182  202778.0000  Youngstown-Warren, OH    OH
# 924                       0.2798   64186.0000          Yuba City, CA    CA
# 925                       0.3556   92808.0000               Yuma, AZ    AZ
# 926                          NaN   38348.0000         Zanesville, OH    OH
# 927                          NaN    6183.0000             Zapata, TX    TX
#
#            city  Population_Size_Category msa_code_bls        Jobs  \
# 0      Aberdeen                         1          NaN         NaN
# 1      Aberdeen                         1          NaN         NaN
# 2       Abilene                         2        10180  78200.0000
# 3           Ada                         1          NaN         NaN
# 4        Adrian                         1          NaN         NaN
# ..          ...                       ...          ...         ...
# 923  Youngstown                         3        49660 211300.0000
# 924   Yuba City                         2        49700  52900.0000
# 925        Yuma                         2        49740  61600.0000
# 926  Zanesville                         1          NaN         NaN
# 927      Zapata                         1          NaN         NaN
#
#      5-Year Job Growth     Income  5-Year Income Growth  Unemployment_Rate
# 0                  NaN        NaN                   NaN                NaN
# 1                  NaN        NaN                   NaN                NaN
# 2               0.0831 53747.7200                0.3829             3.8000
# 3                  NaN        NaN                   NaN                NaN
# 4                  NaN        NaN                   NaN                NaN
# ..                 ...        ...                   ...                ...
# 923            -0.0227 44661.2400                0.0732             5.0000
# 924             0.1328 55434.0800                0.2713             7.3000
# 925             0.1039 52416.5200                0.4144            16.3000
# 926                NaN        NaN                   NaN                NaN
# 927                NaN        NaN                   NaN                NaN
#
# [928 rows x 24 columns]

# %% [markdown]
# ### Now merge Building Permit Survey (Supply) data

# %%
### Read in permitted units tidy for all housing types 
### (if you don't see it in your repo, you need to run 
### "helper_functions/permit_cleaning.py" to clean and create the file)

# We will use research conducted by the Federal Reserve Bank of Atlanta, and use
# an approximate 24 months from permit to completion as a lower bound for multifamly
# completions. Single-Family likely takes less time, but that depends on location. 
# In addition, 50-100 units takes approximately 30 months for completion on average.
# Due to the large variance, I will be using an arbitrary 2-year period from
# permit to completion. Every market will have their own average and will be different
# from project-to-project, so the 2-year time-to-completion will be a rule-of-thumb for simplicity.

permits = pd.read_csv("../datasets_manual_download/building_permits/cleaned/permitted_all_housing_types_tidy.csv",
                      dtype={'msa_code':str})

# Permit end year will be more recent than the census end year
previous_year = census_end_year + 1

# Only keep the most recent year
permits = permits[permits['year']==previous_year]
permits.rename(columns={'year':'permit_data_for_year'}, inplace=True)
permits
# Out:
#             msa_name msa_code  permit_data_for_year  sfh_permits  \
# 9        Abilene, TX    10180                  2023     342.0000
# 19         Akron, OH    10420                  2023     709.0000
# 29        Albany, GA    10500                  2023     162.0000
# 39        Albany, OR    10540                  2023     239.0000
# 49        Albany, NY    10580                  2023     976.0000
# ...              ...      ...                   ...          ...
# 3729      Yakima, WA    49420                  2023     453.0000
# 3739        York, PA    49620                  2023     983.0000
# 3749  Youngstown, OH    49660                  2023     282.0000
# 3759   Yuba City, CA    49700                  2023     589.0000
# 3769        Yuma, AZ    49740                  2023     761.0000
#
#       duplex_unit_permits  small_multifamily_unit_permits  \
# 9                 56.0000                         56.0000
# 19                 4.0000                        107.0000
# 29                 2.0000                          6.0000
# 39                52.0000                         59.0000
# 49                40.0000                         95.0000
# ...                   ...                             ...
# 3729              58.0000                        139.0000
# 3739              14.0000                         38.0000
# 3749               0.0000                          8.0000
# 3759              20.0000                         20.0000
# 3769              20.0000                         24.0000
#
#       commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 9                                 64.0000            462.0000      74.0260
# 19                               124.0000            940.0000      75.4255
# 29                                15.0000            183.0000      88.5246
# 39                                79.0000            377.0000      63.3952
# 49                               836.0000           1907.0000      51.1799
# ...                                   ...                 ...          ...
# 3729                              58.0000            650.0000      69.6923
# 3739                             146.0000           1167.0000      84.2331
# 3749                               0.0000            290.0000      97.2414
# 3759                               0.0000            609.0000      96.7159
# 3769                              88.0000            873.0000      87.1707
#
#       percent_duplex  percent_small_multi  percent_large_multi
# 9            12.1212              12.1212              13.8528
# 19            0.4255              11.3830              13.1915
# 29            1.0929               3.2787               8.1967
# 39           13.7931              15.6499              20.9549
# 49            2.0975               4.9816              43.8385
# ...              ...                  ...                  ...
# 3729          8.9231              21.3846               8.9231
# 3739          1.1997               3.2562              12.5107
# 3749          0.0000               2.7586               0.0000
# 3759          3.2841               3.2841               0.0000
# 3769          2.2910               2.7491              10.0802
#
# [384 rows x 12 columns]

# %%
permits[permits['msa_name'].str.contains("Villages")]
# Out:
#               msa_name msa_code  permit_data_for_year  sfh_permits  \
# 3399  The Villages, FL    45540                  2023    3339.0000
#
#       duplex_unit_permits  small_multifamily_unit_permits  \
# 3399               0.0000                          0.0000
#
#       commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 3399                               0.0000           3339.0000     100.0000
#
#       percent_duplex  percent_small_multi  percent_large_multi
# 3399          0.0000               0.0000               0.0000

# %%
census_bls[census_bls['msa_name_original'].str.contains("Villages")]
# Out:
#              msa_name msa_code_census  5-Year Household Growth  \
# 903  The Villages, FL           45540                   0.2281
#
#      1-Year Household Growth  Population  5-Year Population Growth  \
# 903                   0.0466 131832.0000                    0.1291
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 903                    0.0353        0.1640                      NaN
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 903                  NaN                     NaN                 NaN
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units          msa_name_original  \
# 903                          NaN   76923.0000  Wildwood-The Villages, FL
#
#     state      city  Population_Size_Category msa_code_bls       Jobs  \
# 903    FL  Wildwood                         2        45540 41200.0000
#
#      5-Year Job Growth     Income  5-Year Income Growth  Unemployment_Rate
# 903             0.2997 41499.1200                0.0161             5.2000

# %% [markdown]
# ### Now merge it with the main dataset

# %%
# census_bls_permits = census_bls.merge(permits, how='left', left_on='msa_name', right_on='msa_name')
census_bls_permits = census_bls.merge(permits, how='left', on='msa_name')

# Create percent of total units column
census_bls_permits['Permits_as_Percent_of_Total_Units'] = census_bls_permits['total_unit_permits'] / census_bls_permits['Total_Units']
census_bls_permits = census_bls_permits.sort_values('Permits_as_Percent_of_Total_Units', ascending=False).reset_index(drop=True)

# Another cleaning
census_bls_permits.drop(columns=['state','city','msa_code'], inplace=True)
census_bls_permits.rename(columns={'msa_code_census':'msa_code'}, inplace=True)

census_bls_permits.head(3)
# Out:
#            msa_name msa_code  5-Year Household Growth  \
# 0     Salisbury, MD    41540                   0.0550
# 1  Myrtle Beach, SC    34820                   0.1375
# 2  The Villages, FL    45540                   0.2281
#
#    1-Year Household Growth  Population  5-Year Population Growth  \
# 0                   0.0153 128487.0000                    0.0053
# 1                   0.0578 356578.0000                    0.1496
# 2                   0.0466 131832.0000                    0.1291
#
#    1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                    0.0034        0.1162              248500.0000
# 1                    0.0340        0.3114              316800.0000
# 2                    0.0353        0.1640                      NaN
#
#    5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0               0.0720               1021.0000              0.2391
# 1               0.6271               1108.0000              0.3867
# 2                  NaN                     NaN                 NaN
#
#    ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 0                       0.4109   54646.0000
# 1                       0.3497  206764.0000
# 2                          NaN   76923.0000
#
#                             msa_name_original  Population_Size_Category  \
# 0                               Salisbury, MD                         2
# 1  Myrtle Beach-Conway-North Myrtle Beach, SC                         3
# 2                   Wildwood-The Villages, FL                         2
#
#   msa_code_bls        Jobs  5-Year Job Growth     Income  \
# 0        41540 180800.0000             0.0290 47292.9600
# 1        34820 202800.0000             0.1118 44395.5200
# 2        45540  41200.0000             0.2997 41499.1200
#
#    5-Year Income Growth  Unemployment_Rate  permit_data_for_year  sfh_permits  \
# 0                0.2144             3.8000             2023.0000    4177.0000
# 1                0.3483             5.5000             2023.0000   11228.0000
# 2                0.0161             5.2000             2023.0000    3339.0000
#
#    duplex_unit_permits  small_multifamily_unit_permits  \
# 0              90.0000                        110.0000
# 1              78.0000                        159.0000
# 2               0.0000                          0.0000
#
#    commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 0                             607.0000           4894.0000      85.3494
# 1                            1789.0000          13176.0000      85.2155
# 2                               0.0000           3339.0000     100.0000
#
#    percent_duplex  percent_small_multi  percent_large_multi  \
# 0          1.8390               2.2477              12.4029
# 1          0.5920               1.2067              13.5777
# 2          0.0000               0.0000               0.0000
#
#    Permits_as_Percent_of_Total_Units
# 0                             0.0896
# 1                             0.0637
# 2                             0.0434

# %% [markdown]
# ### Now merge with market pulse data (price and rent), HPI, and RPI data from HouseCanary
# (In Snowflake, I simply queried the `MARKETDATA_DB.RAW.HOUSECANARY_MSA_HISTORICAL_MARKET_PULSE` and `MARKETDATA_DB.RAW.HOUSECANARY_MSA_HISTORICAL_RENTAL_MARKET_PULSE` tables where the DATE_ACCESSED was from the most recent API pull, then I simply downloaded those queries to csv's. You'll see their name and folder location in the code below.)
#
# I also queried `MARKETDATA_DB.RAW.HOUSECANARY_MSA_HPI_FORECAST` and `MARKETDATA_DB.RAW.HOUSECANARY_MSA_RPI_FORECAST` to get the HPI and RPI data as well.

# %%
# Read in median price
hc_market = pd.read_csv(
    "../downloaded_datasets/transferred_from_house_canary_repo/msa_outputs/msa_historical_market_pulse.csv",
    dtype={'MSA_CODE':str})
hc_market = hc_market[['MSA_CODE','PRICECLOSEDMEDIAN']]
hc_market.rename(
    columns={'MSA_CODE':'msa_code', 'PRICECLOSEDMEDIAN':'housecanary_median_price'}, inplace=True)
hc_market = hc_market.dropna()

# Read in median rent
hc_rent_market = pd.read_csv(
    "../downloaded_datasets/transferred_from_house_canary_repo/msa_outputs/msa_historical_rental_market_pulse.csv",
    dtype={'MSA_CODE':str})
for col in hc_rent_market.columns:
    hc_rent_market.rename(columns={col:col.lower()}, inplace=True)

# Only keep markets with enough listing data
hc_rent_market = hc_rent_market[
    hc_rent_market['listingsonmarketcount']>=hc_rent_market['listingsonmarketcount'].quantile(0.25)]

# Only keep specific columns
hc_rent_market = hc_rent_market[['msa_code',
                                #  'msa_name',
                                 'priceonmarketmedian']]
hc_rent_market.rename(columns={'priceonmarketmedian':'housecanary_median_rent'}, inplace=True)

hc_rent_market

# Now merge the two
hc_price_and_rent = hc_market.merge(hc_rent_market, how='inner', on='msa_code')
hc_price_and_rent['housecanary_rentpriceratio'] = 100 * hc_price_and_rent['housecanary_median_rent'] / hc_price_and_rent['housecanary_median_price']

hc_price_and_rent.sort_values('housecanary_rentpriceratio', ascending=False)
# Out:
#     msa_code  housecanary_median_price  housecanary_median_rent  \
# 77     46540               223650.0000                2300.0000
# 102    15380               250000.0000                2525.0000
# 63     44100               205000.0000                1998.0000
# 53     13780               206250.0000                2000.0000
# 150    22420               213450.0000                2050.0000
# ..       ...                       ...                      ...
# 50     12700               780000.0000                3000.0000
# 6      41860              1297500.0000                4500.0000
# 17     46520              1145000.0000                3700.0000
# 42     17980               433950.0000                1272.0000
# 28     41940              1731000.0000                4696.0000
#
#      housecanary_rentpriceratio
# 77                       1.0284
# 102                      1.0100
# 63                       0.9746
# 53                       0.9697
# 150                      0.9604
# ..                          ...
# 50                       0.3846
# 6                        0.3468
# 17                       0.3231
# 42                       0.2931
# 28                       0.2713
#
# [152 rows x 4 columns]

# %%
### Merge now with the main dataset
census_bls_permits_housecanary = census_bls_permits.merge(hc_price_and_rent, how='left', on='msa_code')
census_bls_permits_housecanary
# Out:
#              msa_name msa_code  5-Year Household Growth  \
# 0       Salisbury, MD    41540                   0.0550
# 1    Myrtle Beach, SC    34820                   0.1375
# 2    The Villages, FL    45540                   0.2281
# 3         Sherman, TX    43300                   0.0954
# 4          Austin, TX    12420                   0.2500
# ..                ...      ...                      ...
# 923       Wooster, OH    49300                   0.0197
# 924   Worthington, MN    49380                  -0.0288
# 925       Yankton, SD    49460                   0.0545
# 926    Zanesville, OH    49780                   0.0073
# 927        Zapata, TX    49820                   0.0276
#
#      1-Year Household Growth   Population  5-Year Population Growth  \
# 0                     0.0153  128487.0000                    0.0053
# 1                     0.0578  356578.0000                    0.1496
# 2                     0.0466  131832.0000                    0.1291
# 3                     0.0208  137008.0000                    0.0861
# 4                     0.0501 2296377.0000                    0.1478
# ..                       ...          ...                       ...
# 923                   0.0055  116680.0000                    0.0066
# 924                   0.0109   22194.0000                    0.0156
# 925                   0.0137   23311.0000                    0.0287
# 926                   0.0185   86393.0000                    0.0054
# 927                   0.0433   13896.0000                   -0.0360
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                      0.0034        0.1162              248500.0000
# 1                      0.0340        0.3114              316800.0000
# 2                      0.0353        0.1640                      NaN
# 3                      0.0209        0.1161              281700.0000
# 4                      0.0278        0.0567              487200.0000
# ..                        ...           ...                      ...
# 923                   -0.0015        0.0524                      NaN
# 924                   -0.0013        0.0873                      NaN
# 925                    0.0042        0.0592                      NaN
# 926                    0.0005        0.0978                      NaN
# 927                   -0.0035        0.2593                      NaN
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0                 0.0720               1021.0000              0.2391
# 1                 0.6271               1108.0000              0.3867
# 2                    NaN                     NaN                 NaN
# 3                 0.7272               1112.0000              0.5129
# 4                 0.6000               1596.0000              0.3842
# ..                   ...                     ...                 ...
# 923                  NaN                     NaN                 NaN
# 924                  NaN                     NaN                 NaN
# 925                  NaN                     NaN                 NaN
# 926                  NaN                     NaN                 NaN
# 927                  NaN                     NaN                 NaN
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 0                         0.4109   54646.0000
# 1                         0.3497  206764.0000
# 2                            NaN   76923.0000
# 3                         0.3947   58923.0000
# 4                         0.3276  960087.0000
# ..                           ...          ...
# 923                          NaN   46649.0000
# 924                          NaN    8424.0000
# 925                          NaN   10405.0000
# 926                          NaN   38348.0000
# 927                          NaN    6183.0000
#
#                               msa_name_original  Population_Size_Category  \
# 0                                 Salisbury, MD                         2
# 1    Myrtle Beach-Conway-North Myrtle Beach, SC                         3
# 2                     Wildwood-The Villages, FL                         2
# 3                           Sherman-Denison, TX                         2
# 4              Austin-Round Rock-San Marcos, TX                         5
# ..                                          ...                       ...
# 923                                 Wooster, OH                         2
# 924                             Worthington, MN                         1
# 925                                 Yankton, SD                         1
# 926                              Zanesville, OH                         1
# 927                                  Zapata, TX                         1
#
#     msa_code_bls         Jobs  5-Year Job Growth     Income  \
# 0          41540  180800.0000             0.0290 47292.9600
# 1          34820  202800.0000             0.1118 44395.5200
# 2          45540   41200.0000             0.2997 41499.1200
# 3          43300   54300.0000             0.1082 62283.5200
# 4          12420 1350200.0000             0.2046 63908.5200
# ..           ...          ...                ...        ...
# 923          NaN          NaN                NaN        NaN
# 924          NaN          NaN                NaN        NaN
# 925          NaN          NaN                NaN        NaN
# 926          NaN          NaN                NaN        NaN
# 927          NaN          NaN                NaN        NaN
#
#      5-Year Income Growth  Unemployment_Rate  permit_data_for_year  \
# 0                  0.2144             3.8000             2023.0000
# 1                  0.3483             5.5000             2023.0000
# 2                  0.0161             5.2000             2023.0000
# 3                  0.4483             4.2000             2023.0000
# 4                  0.1591             3.7000             2023.0000
# ..                    ...                ...                   ...
# 923                   NaN                NaN                   NaN
# 924                   NaN                NaN                   NaN
# 925                   NaN                NaN                   NaN
# 926                   NaN                NaN                   NaN
# 927                   NaN                NaN                   NaN
#
#      sfh_permits  duplex_unit_permits  small_multifamily_unit_permits  \
# 0      4177.0000              90.0000                        110.0000
# 1     11228.0000              78.0000                        159.0000
# 2      3339.0000               0.0000                          0.0000
# 3      1162.0000              26.0000                         26.0000
# 4     16532.0000             244.0000                        488.0000
# ..           ...                  ...                             ...
# 923          NaN                  NaN                             NaN
# 924          NaN                  NaN                             NaN
# 925          NaN                  NaN                             NaN
# 926          NaN                  NaN                             NaN
# 927          NaN                  NaN                             NaN
#
#      commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 0                               607.0000           4894.0000      85.3494
# 1                              1789.0000          13176.0000      85.2155
# 2                                 0.0000           3339.0000     100.0000
# 3                              1259.0000           2447.0000      47.4867
# 4                             21753.0000          38773.0000      42.6379
# ..                                   ...                 ...          ...
# 923                                  NaN                 NaN          NaN
# 924                                  NaN                 NaN          NaN
# 925                                  NaN                 NaN          NaN
# 926                                  NaN                 NaN          NaN
# 927                                  NaN                 NaN          NaN
#
#      percent_duplex  percent_small_multi  percent_large_multi  \
# 0            1.8390               2.2477              12.4029
# 1            0.5920               1.2067              13.5777
# 2            0.0000               0.0000               0.0000
# 3            1.0625               1.0625              51.4508
# 4            0.6293               1.2586              56.1035
# ..              ...                  ...                  ...
# 923             NaN                  NaN                  NaN
# 924             NaN                  NaN                  NaN
# 925             NaN                  NaN                  NaN
# 926             NaN                  NaN                  NaN
# 927             NaN                  NaN                  NaN
#
#      Permits_as_Percent_of_Total_Units  housecanary_median_price  \
# 0                               0.0896               415000.0000
# 1                               0.0637               367750.0000
# 2                               0.0434               335495.0000
# 3                               0.0415                       NaN
# 4                               0.0404               418000.0000
# ..                                 ...                       ...
# 923                                NaN                       NaN
# 924                                NaN                       NaN
# 925                                NaN                       NaN
# 926                                NaN                       NaN
# 927                                NaN                       NaN
#
#      housecanary_median_rent  housecanary_rentpriceratio
# 0                  2450.0000                      0.5904
# 1                  2251.0000                      0.6121
# 2                  2275.0000                      0.6781
# 3                        NaN                         NaN
# 4                  2295.0000                      0.5490
# ..                       ...                         ...
# 923                      NaN                         NaN
# 924                      NaN                         NaN
# 925                      NaN                         NaN
# 926                      NaN                         NaN
# 927                      NaN                         NaN
#
# [928 rows x 36 columns]

# %% [markdown]
# Now merge HPI and RPI forecasts

# %%
hpi = pd.read_csv("../downloaded_datasets/transferred_from_house_canary_repo/msa_outputs/msa_hpi_forecast.csv",
                  dtype={'MSA_CODE':str})
hpi['MONTH'] = pd.to_datetime(hpi['MONTH'])

# Get the current and 1-year HPI to determine growth
min_year = hpi['MONTH'].min()
one_year_from_now = min_year + pd.DateOffset(years=1)
hpi = hpi[(hpi['MONTH']==min_year) | (hpi['MONTH']==one_year_from_now)]

hpi.sort_values(["MSA_NAME","MONTH"], ascending=[True, True], inplace=True)

# Create 1-year forecast
hpi['hpi_value_pct_change'] = hpi['HPI_VALUE'].pct_change()
hpi['hpi_real_pct_change'] = hpi['HPI_REAL'].pct_change()
hpi['hpi_trend_pct_change'] = hpi['HPI_TREND'].pct_change()
hpi = hpi[hpi['MONTH']==one_year_from_now]

# Keep key columns
hpi = hpi[['MSA_CODE','hpi_value_pct_change']]

# Rename
hpi.rename(columns={'MSA_CODE':'msa_code','hpi_value_pct_change':'1-Year Price Forecast'}, 
           inplace=True)

hpi
# Out:
#       msa_code  1-Year Price Forecast
# 8580     10180                 0.0382
# 13728    10420                 0.0709
# 2709     10500                 0.0325
# 9948     10540                 0.0303
# 5820     10580                 0.0634
# ...        ...                    ...
# 11928    49420                 0.0420
# 2673     49620                 0.0500
# 2781     49660                 0.0614
# 13152    49700                 0.0220
# 6032     49740                 0.0364
#
# [384 rows x 2 columns]

# %%
rpi = pd.read_csv("../downloaded_datasets/transferred_from_house_canary_repo/msa_outputs/msa_rpi_forecast.csv",
                  dtype={'MSA_CODE':str})
rpi['MONTH'] = pd.to_datetime(rpi['MONTH'])

# Get the current and 1-year RPI to determine growth
min_year = rpi['MONTH'].min()
one_year_from_now = rpi['MONTH'].max()
rpi = rpi[(rpi['MONTH']==min_year) | (rpi['MONTH']==one_year_from_now)]

rpi.sort_values(["MSA_NAME","MONTH"], ascending=[True, True], inplace=True)

# Create 1-year forecast
rpi['rpi_value_pct_change'] = rpi['RPI_VALUE'].pct_change()
rpi = rpi[rpi['MONTH']==one_year_from_now]

# Keep key columns
rpi = rpi[['MSA_CODE','rpi_value_pct_change']]
rpi.rename(columns={'MSA_CODE':'msa_code','rpi_value_pct_change':'1-Year Rent Forecast'}, 
           inplace=True)

rpi
# Out:
#      msa_code  1-Year Rent Forecast
# 836     10180                0.0205
# 1972    10420                0.0249
# 1160    10580                0.0544
# 1403    10740                0.0245
# 535     10900                0.0022
# ...       ...                   ...
# 1052    49020                0.0373
# 2135    49180                0.0175
# 1333    49340                0.0342
# 1843    49620                0.0421
# 1867    49660                0.0505
#
# [201 rows x 2 columns]

# %%
### Now join the two
hpi_rpi = hpi.merge(rpi, how='left', on='msa_code')
hpi_rpi
# Out:
#     msa_code  1-Year Price Forecast  1-Year Rent Forecast
# 0      10180                 0.0382                0.0205
# 1      10420                 0.0709                0.0249
# 2      10500                 0.0325                   NaN
# 3      10540                 0.0303                   NaN
# 4      10580                 0.0634                0.0544
# ..       ...                    ...                   ...
# 379    49420                 0.0420                   NaN
# 380    49620                 0.0500                0.0421
# 381    49660                 0.0614                0.0505
# 382    49700                 0.0220                   NaN
# 383    49740                 0.0364                   NaN
#
# [384 rows x 3 columns]

# %%
### Mow merge with the main dataset
census_bls_permits_housecanary_forecasts = census_bls_permits_housecanary.merge(hpi_rpi,
    how='left', on='msa_code')
census_bls_permits_housecanary_forecasts
# Out:
#              msa_name msa_code  5-Year Household Growth  \
# 0       Salisbury, MD    41540                   0.0550
# 1    Myrtle Beach, SC    34820                   0.1375
# 2    The Villages, FL    45540                   0.2281
# 3         Sherman, TX    43300                   0.0954
# 4          Austin, TX    12420                   0.2500
# ..                ...      ...                      ...
# 923       Wooster, OH    49300                   0.0197
# 924   Worthington, MN    49380                  -0.0288
# 925       Yankton, SD    49460                   0.0545
# 926    Zanesville, OH    49780                   0.0073
# 927        Zapata, TX    49820                   0.0276
#
#      1-Year Household Growth   Population  5-Year Population Growth  \
# 0                     0.0153  128487.0000                    0.0053
# 1                     0.0578  356578.0000                    0.1496
# 2                     0.0466  131832.0000                    0.1291
# 3                     0.0208  137008.0000                    0.0861
# 4                     0.0501 2296377.0000                    0.1478
# ..                       ...          ...                       ...
# 923                   0.0055  116680.0000                    0.0066
# 924                   0.0109   22194.0000                    0.0156
# 925                   0.0137   23311.0000                    0.0287
# 926                   0.0185   86393.0000                    0.0054
# 927                   0.0433   13896.0000                   -0.0360
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                      0.0034        0.1162              248500.0000
# 1                      0.0340        0.3114              316800.0000
# 2                      0.0353        0.1640                      NaN
# 3                      0.0209        0.1161              281700.0000
# 4                      0.0278        0.0567              487200.0000
# ..                        ...           ...                      ...
# 923                   -0.0015        0.0524                      NaN
# 924                   -0.0013        0.0873                      NaN
# 925                    0.0042        0.0592                      NaN
# 926                    0.0005        0.0978                      NaN
# 927                   -0.0035        0.2593                      NaN
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0                 0.0720               1021.0000              0.2391
# 1                 0.6271               1108.0000              0.3867
# 2                    NaN                     NaN                 NaN
# 3                 0.7272               1112.0000              0.5129
# 4                 0.6000               1596.0000              0.3842
# ..                   ...                     ...                 ...
# 923                  NaN                     NaN                 NaN
# 924                  NaN                     NaN                 NaN
# 925                  NaN                     NaN                 NaN
# 926                  NaN                     NaN                 NaN
# 927                  NaN                     NaN                 NaN
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 0                         0.4109   54646.0000
# 1                         0.3497  206764.0000
# 2                            NaN   76923.0000
# 3                         0.3947   58923.0000
# 4                         0.3276  960087.0000
# ..                           ...          ...
# 923                          NaN   46649.0000
# 924                          NaN    8424.0000
# 925                          NaN   10405.0000
# 926                          NaN   38348.0000
# 927                          NaN    6183.0000
#
#                               msa_name_original  Population_Size_Category  \
# 0                                 Salisbury, MD                         2
# 1    Myrtle Beach-Conway-North Myrtle Beach, SC                         3
# 2                     Wildwood-The Villages, FL                         2
# 3                           Sherman-Denison, TX                         2
# 4              Austin-Round Rock-San Marcos, TX                         5
# ..                                          ...                       ...
# 923                                 Wooster, OH                         2
# 924                             Worthington, MN                         1
# 925                                 Yankton, SD                         1
# 926                              Zanesville, OH                         1
# 927                                  Zapata, TX                         1
#
#     msa_code_bls         Jobs  5-Year Job Growth     Income  \
# 0          41540  180800.0000             0.0290 47292.9600
# 1          34820  202800.0000             0.1118 44395.5200
# 2          45540   41200.0000             0.2997 41499.1200
# 3          43300   54300.0000             0.1082 62283.5200
# 4          12420 1350200.0000             0.2046 63908.5200
# ..           ...          ...                ...        ...
# 923          NaN          NaN                NaN        NaN
# 924          NaN          NaN                NaN        NaN
# 925          NaN          NaN                NaN        NaN
# 926          NaN          NaN                NaN        NaN
# 927          NaN          NaN                NaN        NaN
#
#      5-Year Income Growth  Unemployment_Rate  permit_data_for_year  \
# 0                  0.2144             3.8000             2023.0000
# 1                  0.3483             5.5000             2023.0000
# 2                  0.0161             5.2000             2023.0000
# 3                  0.4483             4.2000             2023.0000
# 4                  0.1591             3.7000             2023.0000
# ..                    ...                ...                   ...
# 923                   NaN                NaN                   NaN
# 924                   NaN                NaN                   NaN
# 925                   NaN                NaN                   NaN
# 926                   NaN                NaN                   NaN
# 927                   NaN                NaN                   NaN
#
#      sfh_permits  duplex_unit_permits  small_multifamily_unit_permits  \
# 0      4177.0000              90.0000                        110.0000
# 1     11228.0000              78.0000                        159.0000
# 2      3339.0000               0.0000                          0.0000
# 3      1162.0000              26.0000                         26.0000
# 4     16532.0000             244.0000                        488.0000
# ..           ...                  ...                             ...
# 923          NaN                  NaN                             NaN
# 924          NaN                  NaN                             NaN
# 925          NaN                  NaN                             NaN
# 926          NaN                  NaN                             NaN
# 927          NaN                  NaN                             NaN
#
#      commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 0                               607.0000           4894.0000      85.3494
# 1                              1789.0000          13176.0000      85.2155
# 2                                 0.0000           3339.0000     100.0000
# 3                              1259.0000           2447.0000      47.4867
# 4                             21753.0000          38773.0000      42.6379
# ..                                   ...                 ...          ...
# 923                                  NaN                 NaN          NaN
# 924                                  NaN                 NaN          NaN
# 925                                  NaN                 NaN          NaN
# 926                                  NaN                 NaN          NaN
# 927                                  NaN                 NaN          NaN
#
#      percent_duplex  percent_small_multi  percent_large_multi  \
# 0            1.8390               2.2477              12.4029
# 1            0.5920               1.2067              13.5777
# 2            0.0000               0.0000               0.0000
# 3            1.0625               1.0625              51.4508
# 4            0.6293               1.2586              56.1035
# ..              ...                  ...                  ...
# 923             NaN                  NaN                  NaN
# 924             NaN                  NaN                  NaN
# 925             NaN                  NaN                  NaN
# 926             NaN                  NaN                  NaN
# 927             NaN                  NaN                  NaN
#
#      Permits_as_Percent_of_Total_Units  housecanary_median_price  \
# 0                               0.0896               415000.0000
# 1                               0.0637               367750.0000
# 2                               0.0434               335495.0000
# 3                               0.0415                       NaN
# 4                               0.0404               418000.0000
# ..                                 ...                       ...
# 923                                NaN                       NaN
# 924                                NaN                       NaN
# 925                                NaN                       NaN
# 926                                NaN                       NaN
# 927                                NaN                       NaN
#
#      housecanary_median_rent  housecanary_rentpriceratio  \
# 0                  2450.0000                      0.5904
# 1                  2251.0000                      0.6121
# 2                  2275.0000                      0.6781
# 3                        NaN                         NaN
# 4                  2295.0000                      0.5490
# ..                       ...                         ...
# 923                      NaN                         NaN
# 924                      NaN                         NaN
# 925                      NaN                         NaN
# 926                      NaN                         NaN
# 927                      NaN                         NaN
#
#      1-Year Price Forecast  1-Year Rent Forecast
# 0                   0.0477                0.0493
# 1                   0.0218               -0.0039
# 2                   0.0147                0.0443
# 3                   0.0284               -0.0033
# 4                   0.0289               -0.0369
# ..                     ...                   ...
# 923                    NaN                   NaN
# 924                    NaN                   NaN
# 925                    NaN                   NaN
# 926                    NaN                   NaN
# 927                    NaN                   NaN
#
# [928 rows x 38 columns]

# %% [markdown]
# ### Now merge Taxes and Insurance

# %%
### Read in insurance
insurance = pd.read_csv("../datasets_manual_download/Insurance_and_PropTax/avg_insurance_2024.csv")
insurance.head(5)
# Out:
#    insurance state
# 0       2064    AK
# 1       3798    AL
# 2       4675    AR
# 3       3063    AZ
# 4       1772    CA

# %%
### Read in proptaxes
msa_taxes = pd.read_csv(
    "../datasets_manual_download/Insurance_and_PropTax/proptaxes_by_msa.csv",
    dtype={'msa_code':str})
msa_taxes = clean_BLS_msa_names(msa_taxes)

# Merge with insurance
msa_taxes_insurance = msa_taxes.merge(insurance, how='left', on='state')

# Only keep relevant columns
msa_taxes_insurance = msa_taxes_insurance[['msa_code',
                                           'state',
                                           'metro_or_micro_area',
                                           'median_prop_taxes_by_msa','insurance']]

msa_taxes_insurance.head(5)
# Out:
#   msa_code state            metro_or_micro_area  median_prop_taxes_by_msa  \
# 0    10100    SD  Micropolitan Statistical Area                 2277.0000
# 1    10140    WA  Micropolitan Statistical Area                 1977.0000
# 2    10180    TX  Metropolitan Statistical Area                 2256.0000
# 3    10220    OK  Micropolitan Statistical Area                  866.0000
# 4    10300    MI  Micropolitan Statistical Area                 2188.0000
#
#    insurance
# 0  3970.0000
# 1  2017.0000
# 2  4643.0000
# 3  7012.0000
# 4  2956.0000

# %%
### Now merge with main dataset
biggerscore_v1 = census_bls_permits_housecanary_forecasts.merge(
    msa_taxes_insurance, how='left', on='msa_code')

# FOR TESTING PURPOSES, CREATE A COLUMN THAT RELATES 1-YEAR HOUSEHOLD GROWTH 
# TO PERMITS AS PERCENTAGE OF TOTAL UNITS
biggerscore_v1['1-Year_HH_Growth_Minus_Percent_New_Supply'] = biggerscore_v1['1-Year Household Growth'] - biggerscore_v1['Permits_as_Percent_of_Total_Units']

biggerscore_v1
# Out:
#              msa_name msa_code  5-Year Household Growth  \
# 0       Salisbury, MD    41540                   0.0550
# 1    Myrtle Beach, SC    34820                   0.1375
# 2    The Villages, FL    45540                   0.2281
# 3         Sherman, TX    43300                   0.0954
# 4          Austin, TX    12420                   0.2500
# ..                ...      ...                      ...
# 923       Wooster, OH    49300                   0.0197
# 924   Worthington, MN    49380                  -0.0288
# 925       Yankton, SD    49460                   0.0545
# 926    Zanesville, OH    49780                   0.0073
# 927        Zapata, TX    49820                   0.0276
#
#      1-Year Household Growth   Population  5-Year Population Growth  \
# 0                     0.0153  128487.0000                    0.0053
# 1                     0.0578  356578.0000                    0.1496
# 2                     0.0466  131832.0000                    0.1291
# 3                     0.0208  137008.0000                    0.0861
# 4                     0.0501 2296377.0000                    0.1478
# ..                       ...          ...                       ...
# 923                   0.0055  116680.0000                    0.0066
# 924                   0.0109   22194.0000                    0.0156
# 925                   0.0137   23311.0000                    0.0287
# 926                   0.0185   86393.0000                    0.0054
# 927                   0.0433   13896.0000                   -0.0360
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                      0.0034        0.1162              248500.0000
# 1                      0.0340        0.3114              316800.0000
# 2                      0.0353        0.1640                      NaN
# 3                      0.0209        0.1161              281700.0000
# 4                      0.0278        0.0567              487200.0000
# ..                        ...           ...                      ...
# 923                   -0.0015        0.0524                      NaN
# 924                   -0.0013        0.0873                      NaN
# 925                    0.0042        0.0592                      NaN
# 926                    0.0005        0.0978                      NaN
# 927                   -0.0035        0.2593                      NaN
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0                 0.0720               1021.0000              0.2391
# 1                 0.6271               1108.0000              0.3867
# 2                    NaN                     NaN                 NaN
# 3                 0.7272               1112.0000              0.5129
# 4                 0.6000               1596.0000              0.3842
# ..                   ...                     ...                 ...
# 923                  NaN                     NaN                 NaN
# 924                  NaN                     NaN                 NaN
# 925                  NaN                     NaN                 NaN
# 926                  NaN                     NaN                 NaN
# 927                  NaN                     NaN                 NaN
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 0                         0.4109   54646.0000
# 1                         0.3497  206764.0000
# 2                            NaN   76923.0000
# 3                         0.3947   58923.0000
# 4                         0.3276  960087.0000
# ..                           ...          ...
# 923                          NaN   46649.0000
# 924                          NaN    8424.0000
# 925                          NaN   10405.0000
# 926                          NaN   38348.0000
# 927                          NaN    6183.0000
#
#                               msa_name_original  Population_Size_Category  \
# 0                                 Salisbury, MD                         2
# 1    Myrtle Beach-Conway-North Myrtle Beach, SC                         3
# 2                     Wildwood-The Villages, FL                         2
# 3                           Sherman-Denison, TX                         2
# 4              Austin-Round Rock-San Marcos, TX                         5
# ..                                          ...                       ...
# 923                                 Wooster, OH                         2
# 924                             Worthington, MN                         1
# 925                                 Yankton, SD                         1
# 926                              Zanesville, OH                         1
# 927                                  Zapata, TX                         1
#
#     msa_code_bls         Jobs  5-Year Job Growth     Income  \
# 0          41540  180800.0000             0.0290 47292.9600
# 1          34820  202800.0000             0.1118 44395.5200
# 2          45540   41200.0000             0.2997 41499.1200
# 3          43300   54300.0000             0.1082 62283.5200
# 4          12420 1350200.0000             0.2046 63908.5200
# ..           ...          ...                ...        ...
# 923          NaN          NaN                NaN        NaN
# 924          NaN          NaN                NaN        NaN
# 925          NaN          NaN                NaN        NaN
# 926          NaN          NaN                NaN        NaN
# 927          NaN          NaN                NaN        NaN
#
#      5-Year Income Growth  Unemployment_Rate  permit_data_for_year  \
# 0                  0.2144             3.8000             2023.0000
# 1                  0.3483             5.5000             2023.0000
# 2                  0.0161             5.2000             2023.0000
# 3                  0.4483             4.2000             2023.0000
# 4                  0.1591             3.7000             2023.0000
# ..                    ...                ...                   ...
# 923                   NaN                NaN                   NaN
# 924                   NaN                NaN                   NaN
# 925                   NaN                NaN                   NaN
# 926                   NaN                NaN                   NaN
# 927                   NaN                NaN                   NaN
#
#      sfh_permits  duplex_unit_permits  small_multifamily_unit_permits  \
# 0      4177.0000              90.0000                        110.0000
# 1     11228.0000              78.0000                        159.0000
# 2      3339.0000               0.0000                          0.0000
# 3      1162.0000              26.0000                         26.0000
# 4     16532.0000             244.0000                        488.0000
# ..           ...                  ...                             ...
# 923          NaN                  NaN                             NaN
# 924          NaN                  NaN                             NaN
# 925          NaN                  NaN                             NaN
# 926          NaN                  NaN                             NaN
# 927          NaN                  NaN                             NaN
#
#      commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 0                               607.0000           4894.0000      85.3494
# 1                              1789.0000          13176.0000      85.2155
# 2                                 0.0000           3339.0000     100.0000
# 3                              1259.0000           2447.0000      47.4867
# 4                             21753.0000          38773.0000      42.6379
# ..                                   ...                 ...          ...
# 923                                  NaN                 NaN          NaN
# 924                                  NaN                 NaN          NaN
# 925                                  NaN                 NaN          NaN
# 926                                  NaN                 NaN          NaN
# 927                                  NaN                 NaN          NaN
#
#      percent_duplex  percent_small_multi  percent_large_multi  \
# 0            1.8390               2.2477              12.4029
# 1            0.5920               1.2067              13.5777
# 2            0.0000               0.0000               0.0000
# 3            1.0625               1.0625              51.4508
# 4            0.6293               1.2586              56.1035
# ..              ...                  ...                  ...
# 923             NaN                  NaN                  NaN
# 924             NaN                  NaN                  NaN
# 925             NaN                  NaN                  NaN
# 926             NaN                  NaN                  NaN
# 927             NaN                  NaN                  NaN
#
#      Permits_as_Percent_of_Total_Units  housecanary_median_price  \
# 0                               0.0896               415000.0000
# 1                               0.0637               367750.0000
# 2                               0.0434               335495.0000
# 3                               0.0415                       NaN
# 4                               0.0404               418000.0000
# ..                                 ...                       ...
# 923                                NaN                       NaN
# 924                                NaN                       NaN
# 925                                NaN                       NaN
# 926                                NaN                       NaN
# 927                                NaN                       NaN
#
#      housecanary_median_rent  housecanary_rentpriceratio  \
# 0                  2450.0000                      0.5904
# 1                  2251.0000                      0.6121
# 2                  2275.0000                      0.6781
# 3                        NaN                         NaN
# 4                  2295.0000                      0.5490
# ..                       ...                         ...
# 923                      NaN                         NaN
# 924                      NaN                         NaN
# 925                      NaN                         NaN
# 926                      NaN                         NaN
# 927                      NaN                         NaN
#
#      1-Year Price Forecast  1-Year Rent Forecast state  \
# 0                   0.0477                0.0493    MD
# 1                   0.0218               -0.0039    SC
# 2                   0.0147                0.0443    FL
# 3                   0.0284               -0.0033    TX
# 4                   0.0289               -0.0369    TX
# ..                     ...                   ...   ...
# 923                    NaN                   NaN    OH
# 924                    NaN                   NaN    MN
# 925                    NaN                   NaN    SD
# 926                    NaN                   NaN    OH
# 927                    NaN                   NaN    TX
#
#                metro_or_micro_area  median_prop_taxes_by_msa  insurance  \
# 0    Metropolitan Statistical Area                 1932.0000  2131.0000
# 1    Metropolitan Statistical Area                  725.0000  3219.0000
# 2    Metropolitan Statistical Area                 2645.0000  4984.0000
# 3    Metropolitan Statistical Area                 2352.0000  4643.0000
# 4    Metropolitan Statistical Area                 6517.0000  4643.0000
# ..                             ...                       ...        ...
# 923  Micropolitan Statistical Area                 2229.0000  2613.0000
# 924  Micropolitan Statistical Area                 1418.0000  2999.0000
# 925  Micropolitan Statistical Area                 1971.0000  3970.0000
# 926  Micropolitan Statistical Area                 1379.0000  2613.0000
# 927  Micropolitan Statistical Area                  845.0000  4643.0000
#
#      1-Year_HH_Growth_Minus_Percent_New_Supply
# 0                                      -0.0742
# 1                                      -0.0060
# 2                                       0.0032
# 3                                      -0.0207
# 4                                       0.0097
# ..                                         ...
# 923                                        NaN
# 924                                        NaN
# 925                                        NaN
# 926                                        NaN
# 927                                        NaN
#
# [928 rows x 43 columns]

# %% [markdown]
# ### EDA on V1 Dataset, Look for missing data

# %%
usa_msa = biggerscore_v1[
    (biggerscore_v1['metro_or_micro_area'].str.contains("Metro"))
    & (biggerscore_v1['state']!="PR")
    ].copy()

usa_msa.sort_values("5-Year Population Growth", ascending=False).head(20)
usa_msa[usa_msa['Population_Size_Category']>=4].sort_values("5-Year Population Growth", ascending=False).head(20)

usa_msa[usa_msa['Population_Size_Category']>=3].sort_values("5-Year Income Growth", ascending=False).head(20)

usa_msa[usa_msa['Population_Size_Category']>=3].sort_values(
    "Permits_as_Percent_of_Total_Units", ascending=False).head(5)


# usa_msa.sort_values("Vacancy_Rate", ascending=True).head(20)
# Out:
#             msa_name msa_code  5-Year Household Growth  \
# 1   Myrtle Beach, SC    34820                   0.1375
# 4         Austin, TX    12420                   0.2500
# 6       Lakeland, FL    29460                   0.1657
# 9        Raleigh, NC    39580                   0.1372
# 10     Crestview, FL    18880                   0.1255
#
#     1-Year Household Growth   Population  5-Year Population Growth  \
# 1                    0.0578  356578.0000                    0.1496
# 4                    0.0501 2296377.0000                    0.1478
# 6                    0.0433  736229.0000                    0.1287
# 9                    0.0241 1420825.0000                    0.1153
# 10                   0.0255  288639.0000                    0.1057
#
#     1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 1                     0.0340        0.3114              316800.0000
# 4                     0.0278        0.0567              487200.0000
# 6                     0.0324        0.1746              296300.0000
# 9                     0.0209        0.0781              439500.0000
# 10                    0.0211        0.2740              374300.0000
#
#     5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 1                0.6271               1108.0000              0.3867
# 4                0.6000               1596.0000              0.3842
# 6                0.8369               1192.0000              0.5165
# 9                0.6424               1451.0000              0.4990
# 10               0.5687               1458.0000              0.5952
#
#     ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 1                        0.3497  206764.0000
# 4                        0.3276  960087.0000
# 6                        0.4023  320023.0000
# 9                        0.3301  581802.0000
# 10                       0.3895  158152.0000
#
#                              msa_name_original  Population_Size_Category  \
# 1   Myrtle Beach-Conway-North Myrtle Beach, SC                         3
# 4             Austin-Round Rock-San Marcos, TX                         5
# 6                    Lakeland-Winter Haven, FL                         4
# 9                             Raleigh-Cary, NC                         5
# 10      Crestview-Fort Walton Beach-Destin, FL                         3
#
#    msa_code_bls         Jobs  5-Year Job Growth     Income  \
# 1         34820  202800.0000             0.1118 44395.5200
# 4         12420 1350200.0000             0.2046 63908.5200
# 6         29460  278200.0000             0.1773 53181.4400
# 9         39580  751300.0000             0.1619 60454.6800
# 10        18880  134600.0000             0.1226 55722.1600
#
#     5-Year Income Growth  Unemployment_Rate  permit_data_for_year  \
# 1                 0.3483             5.5000             2023.0000
# 4                 0.1591             3.7000             2023.0000
# 6                 0.2650             4.6000             2023.0000
# 9                 0.2049             3.8000             2023.0000
# 10                0.3196             3.3000             2023.0000
#
#     sfh_permits  duplex_unit_permits  small_multifamily_unit_permits  \
# 1    11228.0000              78.0000                        159.0000
# 4    16532.0000             244.0000                        488.0000
# 6     9209.0000             124.0000                        135.0000
# 9    12147.0000              82.0000                         85.0000
# 10    2814.0000              52.0000                         72.0000
#
#     commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 1                             1789.0000          13176.0000      85.2155
# 4                            21753.0000          38773.0000      42.6379
# 6                             3169.0000          12513.0000      73.5955
# 9                             8387.0000          20619.0000      58.9117
# 10                            2710.0000           5596.0000      50.2859
#
#     percent_duplex  percent_small_multi  percent_large_multi  \
# 1           0.5920               1.2067              13.5777
# 4           0.6293               1.2586              56.1035
# 6           0.9910               1.0789              25.3257
# 9           0.3977               0.4122              40.6761
# 10          0.9292               1.2866              48.4274
#
#     Permits_as_Percent_of_Total_Units  housecanary_median_price  \
# 1                              0.0637               367750.0000
# 4                              0.0404               418000.0000
# 6                              0.0391               315770.0000
# 9                              0.0354               460525.0000
# 10                             0.0354               375470.0000
#
#     housecanary_median_rent  housecanary_rentpriceratio  \
# 1                 2251.0000                      0.6121
# 4                 2295.0000                      0.5490
# 6                 2195.0000                      0.6951
# 9                 2195.0000                      0.4766
# 10                2495.0000                      0.6645
#
#     1-Year Price Forecast  1-Year Rent Forecast state  \
# 1                  0.0218               -0.0039    SC
# 4                  0.0289               -0.0369    TX
# 6                  0.0145                0.0008    FL
# 9                  0.0236               -0.0325    NC
# 10                 0.0081               -0.0337    FL
#
#               metro_or_micro_area  median_prop_taxes_by_msa  insurance  \
# 1   Metropolitan Statistical Area                  725.0000  3219.0000
# 4   Metropolitan Statistical Area                 6517.0000  4643.0000
# 6   Metropolitan Statistical Area                 1398.0000  4984.0000
# 9   Metropolitan Statistical Area                 2668.0000  3398.0000
# 10  Metropolitan Statistical Area                 1623.0000  4984.0000
#
#     1-Year_HH_Growth_Minus_Percent_New_Supply
# 1                                     -0.0060
# 4                                      0.0097
# 6                                      0.0042
# 9                                     -0.0113
# 10                                    -0.0099

# %% [markdown]
# ### To begin the weighting, start by creating an algorithm that works for me (Austin)

# %%
# I'll start by only keeping metropolitan areas within the USA (no puerto rico, no micro areas)
usa_msa = biggerscore_v1[
    (biggerscore_v1['metro_or_micro_area'].str.contains("Metro"))
    & (biggerscore_v1['state']!="PR")
    ].copy()

usa_msa[
    (usa_msa['5-Year Household Growth']>=usa_msa['5-Year Household Growth'].quantile(0.25))
    # & (usa_msa['1-Year Household Growth']>=usa_msa['1-Year Household Growth'].quantile(0.25))
    & (usa_msa['5-Year Population Growth']>=usa_msa['5-Year Population Growth'].quantile(0.25))
    # & (usa_msa['1-Year Population Growth']>=usa_msa['1-Year Population Growth'].quantile(0.25))
    & (usa_msa['5-Year Job Growth']>=usa_msa['5-Year Job Growth'].quantile(0.25))
    & (usa_msa['Income']>=usa_msa['Income'].quantile(0.25))
    & (usa_msa['5-Year Income Growth']>=0)
    & (usa_msa['Unemployment_Rate']<=usa_msa['Unemployment_Rate'].quantile(0.75))
    & (usa_msa['median_prop_taxes_by_msa']<=usa_msa['median_prop_taxes_by_msa'].quantile(0.75))
    # & (usa_msa['insurance']<=usa_msa['insurance'].quantile(0.9))
    & (usa_msa['Vacancy_Rate']<=usa_msa['Vacancy_Rate'].quantile(0.5))
    & (usa_msa['Population_Size_Category']>=2)
    # & (usa_msa['Permits_as_Percent_of_Total_Units']<=usa_msa['Permits_as_Percent_of_Total_Units'].quantile(0.9))
    & (usa_msa['5-Year Rent Growth']>=usa_msa['5-Year Rent Growth'].quantile(0.25))
    # & (usa_msa['5-Year Price Growth']>=usa_msa['5-Year Price Growth'].quantile(0.25))

    # ].sort_values("1-Year Price Forecast", ascending=False).head(50)
    ].sort_values("1-Year_HH_Growth_Minus_Percent_New_Supply", ascending=False).head(50)
# Out:
#                  msa_name msa_code  5-Year Household Growth  \
# 45              Logan, UT    30860                   0.1283
# 17              Provo, UT    39340                   0.2001
# 204            Albany, OR    10540                   0.0795
# 203        Harrisburg, PA    25420                   0.0558
# 200          Columbia, MO    17860                   0.0598
# 206       Albuquerque, NM    10740                   0.0651
# 71       Fort Collins, CO    22660                   0.1406
# 219          Cheyenne, WY    16940                   0.0770
# 125         Rochester, MN    40340                   0.0766
# 90              Ogden, UT    36260                   0.1059
# 67   Colorado Springs, CO    17820                   0.1062
# 124             Salem, OR    41420                   0.0722
# 137     Oklahoma City, OK    36420                   0.0966
# 133        Louisville, KY    31140                   0.0578
# 76             Denver, CO    19740                   0.0969
# 225        Sioux City, IA    43580                   0.0337
# 62               Reno, NV    39900                   0.1131
# 193      Grand Rapids, MI    24340                   0.0633
# 88            Spokane, WA    44060                   0.0916
# 64           Richmond, VA    40060                   0.0967
# 24          Nashville, TN    34980                   0.1298
# 102      Indianapolis, IN    26900                   0.0832
# 128           Boulder, CO    14500                   0.0669
# 47     Salt Lake City, UT    41620                   0.1233
# 136      Chambersburg, PA    16540                   0.0412
# 14         Boise City, ID    14260                   0.1533
# 143         Lexington, KY    30460                   0.0622
# 109        Fort Wayne, IN    23060                   0.0583
# 61     Grand Junction, CO    24300                   0.0419
# 38            Phoenix, AZ    38060                   0.1195
# 18       Fayetteville, AR    22220                   0.1247
# 29          Charlotte, NC    16740                   0.1201
# 41          Lafayette, IN    29200                   0.0557
# 110           Wichita, KS    48620                   0.0310
# 25         Huntsville, AL    26620                   0.1346
# 141          Staunton, VA    44420                   0.0446
# 99            Medford, OR    32780                   0.0427
# 16        Idaho Falls, ID    26820                   0.1071
# 9             Raleigh, NC    39580                   0.1372
#
#      1-Year Household Growth   Population  5-Year Population Growth  \
# 45                    0.0333  148804.0000                    0.1154
# 17                    0.0431  677964.0000                    0.1546
# 204                   0.0169  128598.0000                    0.0621
# 203                   0.0168  593318.0000                    0.0501
# 200                   0.0164  211078.0000                    0.0431
# 206                   0.0157  915968.0000                    0.0121
# 71                    0.0253  359363.0000                    0.0858
# 219                   0.0138  100316.0000                    0.0339
# 125                   0.0188  225911.0000                    0.0533
# 90                    0.0221  638359.0000                    0.0818
# 67                    0.0238  755081.0000                    0.0809
# 124                   0.0184  433415.0000                    0.0568
# 137                   0.0165 1428923.0000                    0.0557
# 133                   0.0160 1359331.0000                    0.0303
# 76                    0.0211 2959386.0000                    0.0574
# 225                   0.0104  143534.0000                    0.0412
# 62                    0.0215  550204.0000                    0.0966
# 193                   0.0105 1149649.0000                    0.0420
# 88                    0.0181  585485.0000                    0.0951
# 64                    0.0202 1316145.0000                    0.0552
# 24                    0.0299 2015869.0000                    0.1013
# 102                   0.0158 2088343.0000                    0.0618
# 128                   0.0128  328658.0000                    0.0375
# 47                    0.0211 1254675.0000                    0.0723
# 136                   0.0117  156084.0000                    0.0201
# 14                    0.0334  771602.0000                    0.1392
# 143                   0.0110  515954.0000                    0.0305
# 109                   0.0130  447882.0000                    0.0439
# 61                    0.0181  156131.0000                    0.0493
# 38                    0.0221 4864209.0000                    0.0665
# 18                    0.0287  550596.0000                    0.1204
# 29                    0.0241 2668688.0000                    0.0881
# 41                    0.0196  224515.0000                    0.0067
# 110                   0.0071  646794.0000                    0.0190
# 25                    0.0198  493980.0000                    0.1103
# 141                   0.0025  125355.0000                    0.0422
# 99                    0.0046  222604.0000                    0.0497
# 16                    0.0206  158478.0000                    0.1285
# 9                     0.0241 1420825.0000                    0.1153
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 45                     0.0210        0.0588              466900.0000
# 17                     0.0274        0.0423              566900.0000
# 204                    0.0110        0.0422              398300.0000
# 203                    0.0101        0.0612              259700.0000
# 200                    0.0065        0.0885              259100.0000
# 206                    0.0028        0.0709              297100.0000
# 71                     0.0132        0.0643              574900.0000
# 219                    0.0041        0.0672              357300.0000
# 125                    0.0070        0.0602              308900.0000
# 90                     0.0127        0.0501              487400.0000
# 67                     0.0104        0.0520              472600.0000
# 124                    0.0070        0.0448              437200.0000
# 137                    0.0114        0.0885              244000.0000
# 133                    0.0027        0.0823              253600.0000
# 76                     0.0077        0.0524              611300.0000
# 225                    0.0051        0.0601              192000.0000
# 62                     0.0154        0.0749              509700.0000
# 193                    0.0052        0.0601              293500.0000
# 88                     0.0138        0.0621              417000.0000
# 64                     0.0099        0.0661              357600.0000
# 24                     0.0151        0.0785              437200.0000
# 102                    0.0096        0.0820              278200.0000
# 128                   -0.0002        0.0540              763600.0000
# 47                     0.0080        0.0535              547500.0000
# 136                    0.0032        0.0582              248900.0000
# 14                     0.0279        0.0455              471700.0000
# 143                    0.0030        0.0729              289200.0000
# 109                    0.0088        0.0672              222700.0000
# 61                     0.0093        0.0681              373200.0000
# 38                     0.0160        0.0901              457400.0000
# 18                     0.0233        0.0845              342100.0000
# 29                     0.0165        0.0800              381200.0000
# 41                     0.0051        0.0743              235300.0000
# 110                    0.0036        0.0963              207300.0000
# 25                     0.0220        0.0738              311400.0000
# 141                    0.0072        0.0851              273100.0000
# 99                     0.0042        0.0666              431500.0000
# 16                     0.0240        0.0699              386100.0000
# 9                      0.0209        0.0781              439500.0000
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 45                0.8245               1054.0000              0.6067
# 17                0.7174               1415.0000              0.5150
# 204               0.5663               1181.0000              0.3927
# 203               0.3770                969.0000              0.2344
# 200               0.3481                904.0000              0.2970
# 206               0.4752               1046.0000              0.3497
# 71                0.4434               1575.0000              0.2560
# 219               0.4495                991.0000              0.2837
# 125               0.4170               1132.0000              0.4203
# 90                0.7235               1364.0000              0.5660
# 67                0.6291               1575.0000              0.4858
# 124               0.5991               1214.0000              0.3718
# 137               0.5165                927.0000              0.3262
# 133               0.4207                903.0000              0.3221
# 76                0.4534               1775.0000              0.3781
# 225               0.3675                847.0000              0.2991
# 62                0.4088               1442.0000              0.4522
# 193               0.5488               1077.0000              0.4097
# 88                0.7448               1137.0000              0.4596
# 64                0.4531               1303.0000              0.3996
# 24                0.6693               1412.0000              0.5265
# 102               0.6442               1007.0000              0.3701
# 128               0.3781               1814.0000              0.2793
# 47                0.6631               1491.0000              0.4632
# 136               0.3812                888.0000              0.2814
# 14                0.7840               1379.0000              0.6320
# 143               0.5253                939.0000              0.2934
# 109               0.6411                787.0000              0.2673
# 61                0.6297                998.0000              0.3097
# 38                0.7131               1605.0000              0.6806
# 18                0.9706               1001.0000              0.4918
# 29                0.7689               1353.0000              0.5642
# 41                0.5440                915.0000              0.3358
# 110               0.4346                755.0000              0.2562
# 25                0.6652               1062.0000              0.5757
# 141               0.3061                878.0000              0.2419
# 99                0.4697               1209.0000              0.4042
# 16                0.8797                995.0000              0.5355
# 9                 0.6424               1451.0000              0.4990
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 45                        0.2257   49287.0000
# 17                        0.2496  199201.0000
# 204                       0.2965   52145.0000
# 203                       0.3731  255664.0000
# 200                       0.3489   91879.0000
# 206                       0.3521  395967.0000
# 71                        0.2740  159083.0000
# 219                       0.2774   44389.0000
# 125                       0.3665   97342.0000
# 90                        0.2799  216503.0000
# 67                        0.3333  303174.0000
# 124                       0.2777  162981.0000
# 137                       0.3799  608642.0000
# 133                       0.3561  593113.0000
# 76                        0.2904 1245265.0000
# 225                       0.4411   57929.0000
# 62                        0.2829  234996.0000
# 193                       0.3670  459734.0000
# 88                        0.2727  247356.0000
# 64                        0.3644  553455.0000
# 24                        0.3230  847497.0000
# 102                       0.3620  888218.0000
# 128                       0.2376  141007.0000
# 47                        0.2723  454070.0000
# 136                       0.3568   66443.0000
# 14                        0.2923  298787.0000
# 143                       0.3247  226808.0000
# 109                       0.3534  189593.0000
# 61                        0.2674   67708.0000
# 38                        0.3509 1996937.0000
# 18                        0.2926  223045.0000
# 29                        0.3549 1115218.0000
# 41                        0.3889   95096.0000
# 110                       0.3642  276052.0000
# 25                        0.3410  213929.0000
# 141                       0.3215   55256.0000
# 99                        0.2802   96286.0000
# 16                        0.2577   57036.0000
# 9                         0.3301  581802.0000
#
#                                   msa_name_original  Population_Size_Category  \
# 45                                     Logan, UT-ID                         2
# 17                              Provo-Orem-Lehi, UT                         4
# 204                                      Albany, OR                         2
# 203                         Harrisburg-Carlisle, PA                         4
# 200                                    Columbia, MO                         2
# 206                                 Albuquerque, NM                         4
# 71                        Fort Collins-Loveland, CO                         3
# 219                                    Cheyenne, WY                         2
# 125                                   Rochester, MN                         2
# 90                                        Ogden, UT                         4
# 67                             Colorado Springs, CO                         4
# 124                                       Salem, OR                         3
# 137                               Oklahoma City, OK                         5
# 133              Louisville/Jefferson County, KY-IN                         5
# 76                     Denver-Aurora-Centennial, CO                         5
# 225                            Sioux City, IA-NE-SD                         2
# 62                                         Reno, NV                         4
# 193               Grand Rapids-Wyoming-Kentwood, MI                         5
# 88                       Spokane-Spokane Valley, WA                         4
# 64                                     Richmond, VA                         5
# 24   Nashville-Davidson--Murfreesboro--Franklin, TN                         5
# 102               Indianapolis-Carmel-Greenwood, IN                         5
# 128                                     Boulder, CO                         3
# 47                        Salt Lake City-Murray, UT                         5
# 136                                Chambersburg, PA                         2
# 14                                   Boise City, ID                         4
# 143                           Lexington-Fayette, KY                         4
# 109                                  Fort Wayne, IN                         3
# 61                               Grand Junction, CO                         2
# 38                        Phoenix-Mesa-Chandler, AZ                         5
# 18               Fayetteville-Springdale-Rogers, AR                         4
# 29                Charlotte-Concord-Gastonia, NC-SC                         5
# 41                     Lafayette-West Lafayette, IN                         2
# 110                                     Wichita, KS                         4
# 25                                   Huntsville, AL                         3
# 141                      Staunton-Stuarts Draft, VA                         2
# 99                                      Medford, OR                         2
# 16                                  Idaho Falls, ID                         2
# 9                                  Raleigh-Cary, NC                         5
#
#     msa_code_bls         Jobs  5-Year Job Growth     Income  \
# 45         30860   70200.0000             0.1359 47922.1600
# 17         39340  312400.0000             0.1644 55432.0000
# 204        10540   48200.0000             0.0478 58515.6000
# 203        25420  368700.0000             0.0392 58116.7600
# 200        17860  106800.0000             0.0876 47276.8400
# 206        10740  423900.0000             0.0627 47620.5600
# 71         22660  188700.0000             0.0789 58520.8000
# 219        16940   49100.0000             0.0294 51745.2000
# 125        40340  132900.0000             0.0581 63956.8800
# 90         36260  303700.0000             0.1256 51878.3200
# 67         17820  335400.0000             0.1058 61491.5600
# 124        41420  182100.0000             0.0600 54688.4000
# 137        36420  707300.0000             0.0762 56781.9200
# 133        31140  703700.0000             0.0385 53010.3600
# 76         19740 1639200.0000             0.0525 70649.2800
# 225        43580   90300.0000             0.0250 47790.0800
# 62         39900  269700.0000             0.0875 58572.8000
# 193        24340  586900.0000             0.0367 55095.0400
# 88         44060  272400.0000             0.0670 64350.5200
# 64         40060  729000.0000             0.0611 57579.0800
# 24         34980 1164200.0000             0.1092 60911.2400
# 102        26900 1202600.0000             0.0925 55373.7600
# 128        14500  210800.0000             0.0462 66458.6000
# 47         41620  844000.0000             0.1189 67193.8800
# 136        16540   62100.0000             0.0065 49926.2400
# 14         14260  409400.0000             0.1768 56797.5200
# 143        30460  301500.0000             0.0795 52302.6400
# 109        23060  238100.0000             0.0388 55373.7600
# 61         24300   67600.0000             0.0258 49339.6800
# 38         38060 2444300.0000             0.1212 63516.9600
# 18         22220  312800.0000             0.1620 56077.8400
# 29         16740 1381400.0000             0.1040 63219.5200
# 41         29200  108600.0000             0.0959 46474.4800
# 110        48620  312200.0000             0.0263 52501.2800
# 25         26620  281900.0000             0.1501 69852.6400
# 141        44420   53900.0000             0.0507 52164.8400
# 99         32780   90200.0000             0.0089 57418.4000
# 16         26820   84600.0000             0.1915 58462.5600
# 9          39580  751300.0000             0.1619 60454.6800
#
#      5-Year Income Growth  Unemployment_Rate  permit_data_for_year  \
# 45                 0.0465             3.5000             2023.0000
# 17                 0.0785             4.0000             2023.0000
# 204                0.3933             4.5000             2023.0000
# 203                0.1988             3.8000             2023.0000
# 200                0.2120             3.2000             2023.0000
# 206                0.1029             4.3000             2023.0000
# 71                 0.2373             3.9000             2023.0000
# 219                0.3020             3.4000             2023.0000
# 125                0.2043             3.0000             2023.0000
# 90                 0.1879             3.7000             2023.0000
# 67                 0.1700             4.5000             2023.0000
# 124                0.3602             4.1000             2023.0000
# 137                0.2040             3.3000             2023.0000
# 133                0.2246             4.5000             2023.0000
# 76                 0.2511             4.4000             2023.0000
# 225                0.1873             2.8000             2023.0000
# 62                 0.1284             4.7000             2023.0000
# 193                0.1517             4.0000             2023.0000
# 88                 0.3135             4.7000             2023.0000
# 64                 0.2395             3.6000             2023.0000
# 24                 0.1964             2.9000             2023.0000
# 102                0.0874             4.0000             2023.0000
# 128                0.1382             4.1000             2023.0000
# 47                 0.2873             3.8000             2023.0000
# 136                0.2430             3.7000             2023.0000
# 14                 0.3753             3.6000             2023.0000
# 143                0.1730             4.3000             2023.0000
# 109                0.1522             4.1000             2023.0000
# 61                 0.2632             4.4000             2023.0000
# 38                 0.2263             3.5000             2023.0000
# 18                 0.3701             2.6000             2023.0000
# 29                 0.1332             4.3000             2023.0000
# 41                 0.0665             4.1000             2023.0000
# 110                0.2639             4.1000             2023.0000
# 25                 0.2839             2.8000             2023.0000
# 141                0.2690             3.2000             2023.0000
# 99                 0.3723             4.7000             2023.0000
# 16                 0.1246             3.0000             2023.0000
# 9                  0.2049             3.8000             2023.0000
#
#      sfh_permits  duplex_unit_permits  small_multifamily_unit_permits  \
# 45      693.0000               4.0000                          8.0000
# 17     4663.0000              38.0000                        172.0000
# 204     239.0000              52.0000                         59.0000
# 203    1213.0000              20.0000                         70.0000
# 200     609.0000               4.0000                          4.0000
# 206    2057.0000               0.0000                          0.0000
# 71     1289.0000              12.0000                         39.0000
# 219     165.0000              14.0000                        114.0000
# 125     604.0000               4.0000                         11.0000
# 90     1871.0000               2.0000                        158.0000
# 67     2670.0000             242.0000                        248.0000
# 124     826.0000              74.0000                         86.0000
# 137    5573.0000             556.0000                        756.0000
# 133    2914.0000              98.0000                        145.0000
# 76     9012.0000             164.0000                        276.0000
# 225     220.0000               4.0000                         41.0000
# 62     1992.0000             110.0000                        183.0000
# 193    2405.0000              86.0000                        247.0000
# 88     1706.0000             216.0000                        286.0000
# 64     4590.0000             224.0000                        232.0000
# 24    13842.0000              66.0000                        139.0000
# 102    7252.0000             202.0000                        342.0000
# 128     791.0000              16.0000                         64.0000
# 47     3163.0000              96.0000                        390.0000
# 136     643.0000              24.0000                         24.0000
# 14     6508.0000              38.0000                        268.0000
# 143    1319.0000              20.0000                         70.0000
# 109    1680.0000              44.0000                         50.0000
# 61      527.0000               8.0000                         12.0000
# 38    24708.0000            1730.0000                       1872.0000
# 18     5349.0000             428.0000                        511.0000
# 29    19146.0000             120.0000                        146.0000
# 41      506.0000               2.0000                          2.0000
# 110    1470.0000            1306.0000                       1332.0000
# 25     3908.0000              90.0000                         94.0000
# 141     415.0000               6.0000                          9.0000
# 99      653.0000              14.0000                         63.0000
# 16      857.0000               4.0000                        160.0000
# 9     12147.0000              82.0000                         85.0000
#
#      commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 45                              339.0000           1040.0000      66.6346
# 17                             1346.0000           6181.0000      75.4409
# 204                              79.0000            377.0000      63.3952
# 203                             581.0000           1864.0000      65.0751
# 200                              68.0000            681.0000      89.4273
# 206                             777.0000           2834.0000      72.5829
# 71                             1358.0000           2686.0000      47.9896
# 219                               8.0000            287.0000      57.4913
# 125                             559.0000           1174.0000      51.4480
# 90                             1371.0000           3400.0000      55.0294
# 67                             2359.0000           5277.0000      50.5969
# 124                            1054.0000           1966.0000      42.0142
# 137                             407.0000           6736.0000      82.7346
# 133                            3672.0000           6731.0000      43.2922
# 76                            11362.0000          20650.0000      43.6416
# 225                             104.0000            365.0000      60.2740
# 62                             2096.0000           4271.0000      46.6401
# 193                             951.0000           3603.0000      66.7499
# 88                             1911.0000           3903.0000      43.7100
# 64                             5151.0000           9973.0000      46.0243
# 24                             9577.0000          23558.0000      58.7571
# 102                            4960.0000          12554.0000      57.7664
# 128                             787.0000           1642.0000      48.1730
# 47                             5682.0000           9235.0000      34.2501
# 136                              70.0000            737.0000      87.2456
# 14                             3115.0000           9891.0000      65.7972
# 143                            1053.0000           2442.0000      54.0131
# 109                             706.0000           2436.0000      68.9655
# 61                              707.0000           1246.0000      42.2953
# 38                            19036.0000          45616.0000      54.1652
# 18                             1055.0000           6915.0000      77.3536
# 29                            10127.0000          29419.0000      65.0804
# 41                             1585.0000           2093.0000      24.1758
# 110                             731.0000           3533.0000      41.6077
# 25                             1938.0000           5940.0000      65.7912
# 141                             181.0000            605.0000      68.5950
# 99                              668.0000           1384.0000      47.1821
# 16                              791.0000           1808.0000      47.4004
# 9                              8387.0000          20619.0000      58.9117
#
#      percent_duplex  percent_small_multi  percent_large_multi  \
# 45           0.3846               0.7692              32.5962
# 17           0.6148               2.7827              21.7764
# 204         13.7931              15.6499              20.9549
# 203          1.0730               3.7554              31.1695
# 200          0.5874               0.5874               9.9853
# 206          0.0000               0.0000              27.4171
# 71           0.4468               1.4520              50.5585
# 219          4.8780              39.7213               2.7875
# 125          0.3407               0.9370              47.6150
# 90           0.0588               4.6471              40.3235
# 67           4.5859               4.6996              44.7034
# 124          3.7640               4.3744              53.6114
# 137          8.2542              11.2233               6.0422
# 133          1.4560               2.1542              54.5536
# 76           0.7942               1.3366              55.0218
# 225          1.0959              11.2329              28.4932
# 62           2.5755               4.2847              49.0752
# 193          2.3869               6.8554              26.3947
# 88           5.5342               7.3277              48.9623
# 64           2.2461               2.3263              51.6495
# 24           0.2802               0.5900              40.6529
# 102          1.6090               2.7242              39.5093
# 128          0.9744               3.8977              47.9294
# 47           1.0395               4.2231              61.5268
# 136          3.2564               3.2564               9.4980
# 14           0.3842               2.7095              31.4933
# 143          0.8190               2.8665              43.1204
# 109          1.8062               2.0525              28.9819
# 61           0.6421               0.9631              56.7416
# 38           3.7925               4.1038              41.7310
# 18           6.1894               7.3897              15.2567
# 29           0.4079               0.4963              34.4233
# 41           0.0956               0.0956              75.7286
# 110         36.9658              37.7017              20.6906
# 25           1.5152               1.5825              32.6263
# 141          0.9917               1.4876              29.9174
# 99           1.0116               4.5520              48.2659
# 16           0.2212               8.8496              43.7500
# 9            0.3977               0.4122              40.6761
#
#      Permits_as_Percent_of_Total_Units  housecanary_median_price  \
# 45                              0.0211                       NaN
# 17                              0.0310                       NaN
# 204                             0.0072                       NaN
# 203                             0.0073               247500.0000
# 200                             0.0074                       NaN
# 206                             0.0072               342495.0000
# 71                              0.0169                       NaN
# 219                             0.0065                       NaN
# 125                             0.0121                       NaN
# 90                              0.0157                       NaN
# 67                              0.0174                       NaN
# 124                             0.0121                       NaN
# 137                             0.0111               260068.0000
# 133                             0.0113               295000.0000
# 76                              0.0166               645000.0000
# 225                             0.0063                       NaN
# 62                              0.0182               579990.0000
# 193                             0.0078                       NaN
# 88                              0.0158                       NaN
# 64                              0.0180               399975.0000
# 24                              0.0278               471690.0000
# 102                             0.0141               315000.0000
# 128                             0.0116                       NaN
# 47                              0.0203               600000.0000
# 136                             0.0111                       NaN
# 14                              0.0331               492495.0000
# 143                             0.0108               326500.0000
# 109                             0.0128               270000.0000
# 61                              0.0184                       NaN
# 38                              0.0228               475000.0000
# 18                              0.0310               338745.0000
# 29                              0.0264               420000.0000
# 41                              0.0220                       NaN
# 110                             0.0128                       NaN
# 25                              0.0278               333990.0000
# 141                             0.0109                       NaN
# 99                              0.0144                       NaN
# 16                              0.0317                       NaN
# 9                               0.0354               460525.0000
#
#      housecanary_median_rent  housecanary_rentpriceratio  \
# 45                       NaN                         NaN
# 17                       NaN                         NaN
# 204                      NaN                         NaN
# 203                1995.0000                      0.8061
# 200                      NaN                         NaN
# 206                2345.0000                      0.6847
# 71                       NaN                         NaN
# 219                      NaN                         NaN
# 125                      NaN                         NaN
# 90                       NaN                         NaN
# 67                       NaN                         NaN
# 124                      NaN                         NaN
# 137                1695.0000                      0.6518
# 133                1875.0000                      0.6356
# 76                 3200.0000                      0.4961
# 225                      NaN                         NaN
# 62                 2695.0000                      0.4647
# 193                      NaN                         NaN
# 88                       NaN                         NaN
# 64                 2395.0000                      0.5988
# 24                 2500.0000                      0.5300
# 102                1900.0000                      0.6032
# 128                      NaN                         NaN
# 47                 2815.0000                      0.4692
# 136                      NaN                         NaN
# 14                 2612.0000                      0.5304
# 143                2200.0000                      0.6738
# 109                1850.0000                      0.6852
# 61                       NaN                         NaN
# 38                 2475.0000                      0.5211
# 18                 1995.0000                      0.5889
# 29                 2128.0000                      0.5067
# 41                       NaN                         NaN
# 110                      NaN                         NaN
# 25                 1800.0000                      0.5389
# 141                      NaN                         NaN
# 99                       NaN                         NaN
# 16                       NaN                         NaN
# 9                  2195.0000                      0.4766
#
#      1-Year Price Forecast  1-Year Rent Forecast state  \
# 45                  0.0668                   NaN    UT
# 17                  0.0287                   NaN    UT
# 204                 0.0303                   NaN    OR
# 203                 0.0567                0.0370    PA
# 200                 0.0596                   NaN    MO
# 206                 0.0378                0.0245    NM
# 71                  0.0454                   NaN    CO
# 219                 0.0173                   NaN    WY
# 125                 0.0348                   NaN    MN
# 90                  0.0544                   NaN    UT
# 67                  0.0261                0.0504    CO
# 124                 0.0247                   NaN    OR
# 137                 0.0393                0.0055    OK
# 133                 0.0468                0.0176    KY
# 76                  0.0291                0.0192    CO
# 225                 0.0363                   NaN    IA
# 62                  0.0428                0.0395    NV
# 193                 0.0711                0.0382    MI
# 88                  0.0264                   NaN    WA
# 64                  0.0641                0.0297    VA
# 24                  0.0206                0.0257    TN
# 102                 0.0355                0.0138    IN
# 128                 0.0295                   NaN    CO
# 47                  0.0469                   NaN    UT
# 136                 0.0479                0.0273    PA
# 14                  0.0560               -0.0039    ID
# 143                 0.0611                0.0300    KY
# 109                 0.0551                0.0338    IN
# 61                  0.0443                   NaN    CO
# 38                  0.0227                0.0145    AZ
# 18                  0.0379                0.0295    AR
# 29                  0.0412               -0.0321    NC
# 41                  0.0755                   NaN    IN
# 110                 0.0517                0.0726    KS
# 25                  0.0196                0.0109    AL
# 141                 0.0530                   NaN    VA
# 99                  0.0237                   NaN    OR
# 16                  0.0462                   NaN    ID
# 9                   0.0236               -0.0325    NC
#
#                metro_or_micro_area  median_prop_taxes_by_msa  insurance  \
# 45   Metropolitan Statistical Area                 1596.0000  2161.0000
# 17   Metropolitan Statistical Area                 1817.0000  2161.0000
# 204  Metropolitan Statistical Area                 2793.0000  2185.0000
# 203  Metropolitan Statistical Area                 2958.0000  2130.0000
# 200  Metropolitan Statistical Area                 1943.0000  4114.0000
# 206  Metropolitan Statistical Area                 2273.0000  3489.0000
# 71   Metropolitan Statistical Area                 2281.0000  4662.0000
# 219  Metropolitan Statistical Area                 1549.0000  2490.0000
# 125  Metropolitan Statistical Area                 2897.0000  2999.0000
# 90   Metropolitan Statistical Area                 2115.0000  2161.0000
# 67   Metropolitan Statistical Area                 1449.0000  4662.0000
# 124  Metropolitan Statistical Area                 3034.0000  2185.0000
# 137  Metropolitan Statistical Area                 2045.0000  7012.0000
# 133  Metropolitan Statistical Area                 3058.0000  4153.0000
# 76   Metropolitan Statistical Area                 3187.0000  4662.0000
# 225  Metropolitan Statistical Area                 2715.0000  3230.0000
# 62   Metropolitan Statistical Area                 1978.0000  1853.0000
# 193  Metropolitan Statistical Area                 2716.0000  2956.0000
# 88   Metropolitan Statistical Area                 2711.0000  2017.0000
# 64   Metropolitan Statistical Area                 2500.0000  2694.0000
# 24   Metropolitan Statistical Area                 2588.0000  3737.0000
# 102  Metropolitan Statistical Area                 2887.0000  3620.0000
# 128  Metropolitan Statistical Area                 3164.0000  4662.0000
# 47   Metropolitan Statistical Area                 2365.0000  2161.0000
# 136  Metropolitan Statistical Area                 2422.0000  2130.0000
# 14   Metropolitan Statistical Area                 2229.0000  2449.0000
# 143  Metropolitan Statistical Area                 2038.0000  4153.0000
# 109  Metropolitan Statistical Area                 1305.0000  3620.0000
# 61   Metropolitan Statistical Area                 1139.0000  4662.0000
# 38   Metropolitan Statistical Area                 1734.0000  3063.0000
# 18   Metropolitan Statistical Area                 1442.0000  4675.0000
# 29   Metropolitan Statistical Area                 2489.0000  3398.0000
# 41   Metropolitan Statistical Area                 1192.0000  3620.0000
# 110  Metropolitan Statistical Area                 2655.0000  5688.0000
# 25   Metropolitan Statistical Area                  905.0000  3798.0000
# 141  Metropolitan Statistical Area                 1470.0000  2694.0000
# 99   Metropolitan Statistical Area                 2765.0000  2185.0000
# 16   Metropolitan Statistical Area                 1503.0000  2449.0000
# 9    Metropolitan Statistical Area                 2668.0000  3398.0000
#
#      1-Year_HH_Growth_Minus_Percent_New_Supply
# 45                                      0.0122
# 17                                      0.0120
# 204                                     0.0097
# 203                                     0.0095
# 200                                     0.0090
# 206                                     0.0086
# 71                                      0.0084
# 219                                     0.0074
# 125                                     0.0068
# 90                                      0.0064
# 67                                      0.0064
# 124                                     0.0063
# 137                                     0.0054
# 133                                     0.0047
# 76                                      0.0045
# 225                                     0.0041
# 62                                      0.0033
# 193                                     0.0026
# 88                                      0.0024
# 64                                      0.0021
# 24                                      0.0021
# 102                                     0.0017
# 128                                     0.0012
# 47                                      0.0007
# 136                                     0.0006
# 14                                      0.0003
# 143                                     0.0002
# 109                                     0.0001
# 61                                     -0.0003
# 38                                     -0.0007
# 18                                     -0.0023
# 29                                     -0.0023
# 41                                     -0.0024
# 110                                    -0.0057
# 25                                     -0.0080
# 141                                    -0.0084
# 99                                     -0.0098
# 16                                     -0.0111
# 9                                      -0.0113

# %% [markdown]
# ### Now begin creating the first version of weights

# %%
usa_msa_weighted = usa_msa.copy()
usa_msa_weighted = usa_msa_weighted.dropna()
usa_msa_weighted
# Out:
#               msa_name msa_code  5-Year Household Growth  \
# 0        Salisbury, MD    41540                   0.0550
# 1     Myrtle Beach, SC    34820                   0.1375
# 4           Austin, TX    12420                   0.2500
# 5      Punta Gorda, FL    39460                   0.1307
# 6         Lakeland, FL    29460                   0.1657
# ..                 ...      ...                      ...
# 343        Reading, PA    39740                   0.0474
# 357  Atlantic City, NJ    12100                   0.0669
# 361     Youngstown, OH    49660                  -0.0111
# 362       Rockford, IL    40420                   0.0078
# 363         Peoria, IL    37900                   0.0071
#
#      1-Year Household Growth   Population  5-Year Population Growth  \
# 0                     0.0153  128487.0000                    0.0053
# 1                     0.0578  356578.0000                    0.1496
# 4                     0.0501 2296377.0000                    0.1478
# 5                     0.0232  189900.0000                    0.0962
# 6                     0.0433  736229.0000                    0.1287
# ..                       ...          ...                       ...
# 343                   0.0069  428483.0000                    0.0312
# 357                   0.0181  369795.0000                    0.0063
# 361                   0.0023  429728.0000                   -0.0126
# 362                   0.0008  338050.0000                   -0.0091
# 363                   0.0080  368011.0000                   -0.0245
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                      0.0034        0.1162              248500.0000
# 1                      0.0340        0.3114              316800.0000
# 4                      0.0278        0.0567              487200.0000
# 5                      0.0274        0.2395              365900.0000
# 6                      0.0324        0.1746              296300.0000
# ..                        ...           ...                      ...
# 343                    0.0036        0.0557              261200.0000
# 357                    0.0012        0.3519              350000.0000
# 361                   -0.0035        0.0990              149700.0000
# 362                   -0.0030        0.0756              169500.0000
# 363                   -0.0059        0.0931              160600.0000
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0                 0.0720               1021.0000              0.2391
# 1                 0.6271               1108.0000              0.3867
# 4                 0.6000               1596.0000              0.3842
# 5                 0.7711               1331.0000              0.5074
# 6                 0.8369               1192.0000              0.5165
# ..                   ...                     ...                 ...
# 343               0.4043                996.0000              0.3533
# 357               0.5960               1132.0000              0.2358
# 361               0.3051                626.0000              0.1636
# 362               0.3336                804.0000              0.2427
# 363               0.1455                701.0000              0.1216
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 0                         0.4109   54646.0000
# 1                         0.3497  206764.0000
# 4                         0.3276  960087.0000
# 5                         0.3638  111330.0000
# 6                         0.4023  320023.0000
# ..                           ...          ...
# 343                       0.3813  170678.0000
# 357                       0.3234  231311.0000
# 361                       0.4182  202778.0000
# 362                       0.4743  145222.0000
# 363                       0.4365  167724.0000
#
#                               msa_name_original  Population_Size_Category  \
# 0                                 Salisbury, MD                         2
# 1    Myrtle Beach-Conway-North Myrtle Beach, SC                         3
# 4              Austin-Round Rock-San Marcos, TX                         5
# 5                               Punta Gorda, FL                         2
# 6                     Lakeland-Winter Haven, FL                         4
# ..                                          ...                       ...
# 343                                 Reading, PA                         3
# 357                 Atlantic City-Hammonton, NJ                         3
# 361                       Youngstown-Warren, OH                         3
# 362                                Rockford, IL                         3
# 363                                  Peoria, IL                         3
#
#     msa_code_bls         Jobs  5-Year Job Growth     Income  \
# 0          41540  180800.0000             0.0290 47292.9600
# 1          34820  202800.0000             0.1118 44395.5200
# 4          12420 1350200.0000             0.2046 63908.5200
# 5          39460   56400.0000             0.1394 41264.6000
# 6          29460  278200.0000             0.1773 53181.4400
# ..           ...          ...                ...        ...
# 343        39740  180800.0000             0.0011 63993.8000
# 357        12100  133300.0000            -0.0191 49566.9200
# 361        49660  211300.0000            -0.0227 44661.2400
# 362        40420  146500.0000            -0.0292 60838.9600
# 363        37900  170900.0000            -0.0098 54364.9600
#
#      5-Year Income Growth  Unemployment_Rate  permit_data_for_year  \
# 0                  0.2144             3.8000             2023.0000
# 1                  0.3483             5.5000             2023.0000
# 4                  0.1591             3.7000             2023.0000
# 5                  0.1781             4.2000             2023.0000
# 6                  0.2650             4.6000             2023.0000
# ..                    ...                ...                   ...
# 343                0.3461             4.3000             2023.0000
# 357                0.1094             6.8000             2023.0000
# 361                0.0732             5.0000             2023.0000
# 362                0.3518             6.0000             2023.0000
# 363                0.2791             5.4000             2023.0000
#
#      sfh_permits  duplex_unit_permits  small_multifamily_unit_permits  \
# 0      4177.0000              90.0000                        110.0000
# 1     11228.0000              78.0000                        159.0000
# 4     16532.0000             244.0000                        488.0000
# 5      3804.0000             284.0000                        395.0000
# 6      9209.0000             124.0000                        135.0000
# ..           ...                  ...                             ...
# 343     231.0000              12.0000                         16.0000
# 357     299.0000              44.0000                         44.0000
# 361     282.0000               0.0000                          8.0000
# 362     179.0000              12.0000                         21.0000
# 363     184.0000               4.0000                          4.0000
#
#      commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 0                               607.0000           4894.0000      85.3494
# 1                              1789.0000          13176.0000      85.2155
# 4                             21753.0000          38773.0000      42.6379
# 5                               230.0000           4429.0000      85.8885
# 6                              3169.0000          12513.0000      73.5955
# ..                                   ...                 ...          ...
# 343                             105.0000            352.0000      65.6250
# 357                              40.0000            383.0000      78.0679
# 361                               0.0000            290.0000      97.2414
# 362                               0.0000            200.0000      89.5000
# 363                              22.0000            210.0000      87.6190
#
#      percent_duplex  percent_small_multi  percent_large_multi  \
# 0            1.8390               2.2477              12.4029
# 1            0.5920               1.2067              13.5777
# 4            0.6293               1.2586              56.1035
# 5            6.4123               8.9185               5.1930
# 6            0.9910               1.0789              25.3257
# ..              ...                  ...                  ...
# 343          3.4091               4.5455              29.8295
# 357         11.4883              11.4883              10.4439
# 361          0.0000               2.7586               0.0000
# 362          6.0000              10.5000               0.0000
# 363          1.9048               1.9048              10.4762
#
#      Permits_as_Percent_of_Total_Units  housecanary_median_price  \
# 0                               0.0896               415000.0000
# 1                               0.0637               367750.0000
# 4                               0.0404               418000.0000
# 5                               0.0398               332000.0000
# 6                               0.0391               315770.0000
# ..                                 ...                       ...
# 343                             0.0021               291000.0000
# 357                             0.0017               370000.0000
# 361                             0.0014               177000.0000
# 362                             0.0014               190000.0000
# 363                             0.0013               175000.0000
#
#      housecanary_median_rent  housecanary_rentpriceratio  \
# 0                  2450.0000                      0.5904
# 1                  2251.0000                      0.6121
# 4                  2295.0000                      0.5490
# 5                  2570.0000                      0.7741
# 6                  2195.0000                      0.6951
# ..                       ...                         ...
# 343                2050.0000                      0.7045
# 357                2350.0000                      0.6351
# 361                 975.0000                      0.5508
# 362                1800.0000                      0.9474
# 363                1275.0000                      0.7286
#
#      1-Year Price Forecast  1-Year Rent Forecast state  \
# 0                   0.0477                0.0493    MD
# 1                   0.0218               -0.0039    SC
# 4                   0.0289               -0.0369    TX
# 5                   0.0126               -0.2086    FL
# 6                   0.0145                0.0008    FL
# ..                     ...                   ...   ...
# 343                 0.0631                0.0401    PA
# 357                 0.0806                0.0107    NJ
# 361                 0.0614                0.0505    OH
# 362                 0.0826                0.0512    IL
# 363                 0.0408                0.0461    IL
#
#                metro_or_micro_area  median_prop_taxes_by_msa  insurance  \
# 0    Metropolitan Statistical Area                 1932.0000  2131.0000
# 1    Metropolitan Statistical Area                  725.0000  3219.0000
# 4    Metropolitan Statistical Area                 6517.0000  4643.0000
# 5    Metropolitan Statistical Area                 2064.0000  4984.0000
# 6    Metropolitan Statistical Area                 1398.0000  4984.0000
# ..                             ...                       ...        ...
# 343  Metropolitan Statistical Area                 3893.0000  2130.0000
# 357  Metropolitan Statistical Area                 6373.0000  1894.0000
# 361  Metropolitan Statistical Area                 1827.0000  2613.0000
# 362  Metropolitan Statistical Area                 4118.0000  3587.0000
# 363  Metropolitan Statistical Area                 3873.0000  3587.0000
#
#      1-Year_HH_Growth_Minus_Percent_New_Supply
# 0                                      -0.0742
# 1                                      -0.0060
# 4                                       0.0097
# 5                                      -0.0166
# 6                                       0.0042
# ..                                         ...
# 343                                     0.0049
# 357                                     0.0165
# 361                                     0.0008
# 362                                    -0.0006
# 363                                     0.0068
#
# [139 rows x 43 columns]

# %%
usa_msa_weighted = usa_msa.copy()

# Drop rows where key rows are is empty
usa_msa_weighted = usa_msa_weighted[usa_msa_weighted['Jobs'].notna()]
usa_msa_weighted = usa_msa_weighted[usa_msa_weighted['1-Year_HH_Growth_Minus_Percent_New_Supply'].notna()]


# Make a function for this where the input is the column name
def basic_column_ranking(
        df, 
        col_name, 
        ascending=True):
    
    df = df.sort_values(col_name, ascending=ascending).reset_index(drop=True)
    df[f'RANK_{col_name}'] = df.index + 1

    return df

# Create the base rankings
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "5-Year Household Growth")
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "5-Year Population Growth")
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "5-Year Job Growth")
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "Income")
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "5-Year Income Growth")
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "Unemployment_Rate", ascending=False)
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "1-Year_HH_Growth_Minus_Percent_New_Supply")
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "ACS_1_Year_Rent-Price_Ratio")
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "1-Year Price Forecast")
# usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "1-Year Rent Forecast")
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "insurance", ascending=False)
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "median_prop_taxes_by_msa", ascending=False)
usa_msa_weighted = basic_column_ranking(usa_msa_weighted, "Vacancy_Rate", ascending=False)

usa_msa_weighted.head(5)
# Out:
#               msa_name msa_code  5-Year Household Growth  \
# 0  Barnstable Town, MA    12700                   0.0522
# 1    Atlantic City, NJ    12100                   0.0669
# 2           Naples, FL    34940                   0.1349
# 3     Myrtle Beach, SC    34820                   0.1375
# 4           Daphne, AL    19300                   0.1927
#
#    1-Year Household Growth  Population  5-Year Population Growth  \
# 0                   0.0184 229436.0000                    0.0726
# 1                   0.0181 369795.0000                    0.0063
# 2                   0.0199 380221.0000                    0.0657
# 3                   0.0578 356578.0000                    0.1496
# 4                   0.0414 233420.0000                    0.1478
#
#    1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 0                    0.0066        0.3944              634700.0000
# 1                    0.0012        0.3519              350000.0000
# 2                    0.0199        0.3178              595500.0000
# 3                    0.0340        0.3114              316800.0000
# 4                    0.0277        0.2742              307000.0000
#
#    5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 0               0.5556               1398.0000              0.2572
# 1               0.5960               1132.0000              0.2358
# 2               0.6108               1867.0000              0.6420
# 3               0.6271               1108.0000              0.3867
# 4               0.5841               1089.0000              0.3105
#
#    ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 0                       0.2203  165068.0000
# 1                       0.3234  231311.0000
# 2                       0.3135  229814.0000
# 3                       0.3497  206764.0000
# 4                       0.3547  125113.0000
#
#                             msa_name_original  Population_Size_Category  \
# 0                         Barnstable Town, MA                         2
# 1                 Atlantic City-Hammonton, NJ                         3
# 2                     Naples-Marco Island, FL                         3
# 3  Myrtle Beach-Conway-North Myrtle Beach, SC                         3
# 4                   Daphne-Fairhope-Foley, AL                         2
#
#   msa_code_bls        Jobs  5-Year Job Growth     Income  \
# 0        70900 115900.0000            -0.0508 54119.5200
# 1        12100 133300.0000            -0.0191 49566.9200
# 2        34940 173600.0000             0.1581 50788.4000
# 3        34820 202800.0000             0.1118 44395.5200
# 4        19300  89800.0000             0.1018 43076.2800
#
#    5-Year Income Growth  Unemployment_Rate  permit_data_for_year  sfh_permits  \
# 0                0.2276             4.1000             2023.0000     418.0000
# 1                0.1094             6.8000             2023.0000     299.0000
# 2                0.1160             3.7000             2023.0000    2923.0000
# 3                0.3483             5.5000             2023.0000   11228.0000
# 4                0.2457             3.1000             2023.0000    3316.0000
#
#    duplex_unit_permits  small_multifamily_unit_permits  \
# 0              12.0000                         25.0000
# 1              44.0000                         44.0000
# 2              30.0000                        106.0000
# 3              78.0000                        159.0000
# 4              16.0000                         32.0000
#
#    commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 0                             104.0000            547.0000      76.4168
# 1                              40.0000            383.0000      78.0679
# 2                             589.0000           3618.0000      80.7905
# 3                            1789.0000          13176.0000      85.2155
# 4                            1015.0000           4363.0000      76.0028
#
#    percent_duplex  percent_small_multi  percent_large_multi  \
# 0          2.1938               4.5704              19.0128
# 1         11.4883              11.4883              10.4439
# 2          0.8292               2.9298              16.2797
# 3          0.5920               1.2067              13.5777
# 4          0.3667               0.7334              23.2638
#
#    Permits_as_Percent_of_Total_Units  housecanary_median_price  \
# 0                             0.0033               780000.0000
# 1                             0.0017               370000.0000
# 2                             0.0157               710000.0000
# 3                             0.0637               367750.0000
# 4                             0.0349               360432.0000
#
#    housecanary_median_rent  housecanary_rentpriceratio  1-Year Price Forecast  \
# 0                3000.0000                      0.3846                 0.0487
# 1                2350.0000                      0.6351                 0.0806
# 2                4200.0000                      0.5915                 0.0259
# 3                2251.0000                      0.6121                 0.0218
# 4                2000.0000                      0.5549                 0.0321
#
#    1-Year Rent Forecast state            metro_or_micro_area  \
# 0                0.0041    MA  Metropolitan Statistical Area
# 1                0.0107    NJ  Metropolitan Statistical Area
# 2               -0.1459    FL  Metropolitan Statistical Area
# 3               -0.0039    SC  Metropolitan Statistical Area
# 4               -0.0105    AL  Metropolitan Statistical Area
#
#    median_prop_taxes_by_msa  insurance  \
# 0                 3658.0000  1998.0000
# 1                 6373.0000  1894.0000
# 2                 2807.0000  4984.0000
# 3                  725.0000  3219.0000
# 4                  718.0000  3798.0000
#
#    1-Year_HH_Growth_Minus_Percent_New_Supply  RANK_5-Year Household Growth  \
# 0                                     0.0151                           198
# 1                                     0.0165                           238
# 2                                     0.0041                           346
# 3                                    -0.0060                           349
# 4                                     0.0066                           364
#
#    RANK_5-Year Population Growth  RANK_5-Year Job Growth  RANK_Income  \
# 0                            306                      10          218
# 1                            111                      42          138
# 2                            294                     357          155
# 3                            364                     330           72
# 4                            362                     316           51
#
#    RANK_5-Year Income Growth  RANK_Unemployment_Rate  \
# 0                        218                     184
# 1                         88                      12
# 2                         96                     258
# 3                        327                      42
# 4                        245                     329
#
#    RANK_1-Year_HH_Growth_Minus_Percent_New_Supply  \
# 0                                             350
# 1                                             357
# 2                                             217
# 3                                              29
# 4                                             268
#
#    RANK_ACS_1_Year_Rent-Price_Ratio  RANK_1-Year Price Forecast  \
# 0                                 9                         248
# 1                               120                         357
# 2                               100                          79
# 3                               177                          52
# 4                               194                         126
#
#    RANK_insurance  RANK_median_prop_taxes_by_msa  RANK_Vacancy_Rate
# 0             324                             66                  1
# 1             330                             13                  2
# 2              16                            129                  3
# 3             172                            358                  4
# 4             108                            359                  5

# %%
usa_msa_weighted.to_csv("outputs/ranked_msas.csv", index=False)

# %%
### Create a dictionary to hold the future weights of the RANK columns
rank_weights = {
    'RANK_5-Year Household Growth': 1,
    'RANK_5-Year Population Growth': 1,
    'RANK_5-Year Job Growth': 3,
    'RANK_Income': 2,
    'RANK_5-Year Income Growth': 1,
    'RANK_Unemployment_Rate': 1,
    'RANK_1-Year_HH_Growth_Minus_Percent_New_Supply': 2,
    'RANK_ACS_1_Year_Rent-Price_Ratio': 3,
    'RANK_1-Year Price Forecast': 2,
    # 'RANK_1-Year Rent Forecast': 1,
    'RANK_insurance': 3,
    'RANK_median_prop_taxes_by_msa': 3,
    'RANK_Vacancy_Rate': 2,
    'Population_Size_Category': 250
}

### Create the basic sums of the ranks
usa_msa_weighted['Total_Rank_Sum'] = 0
for col in rank_weights:
    usa_msa_weighted['Total_Rank_Sum'] += usa_msa_weighted[col] * rank_weights[col]

usa_msa_weighted.sort_values("Total_Rank_Sum", ascending=False).head(10)
# Out:
#                msa_name msa_code  5-Year Household Growth  \
# 344  Salt Lake City, UT    41620                   0.1233
# 360      Boise City, ID    14260                   0.1533
# 298        Richmond, VA    40060                   0.0967
# 114      Charleston, SC    16700                   0.1324
# 314      Harrisburg, PA    25420                   0.0558
# 350           Ogden, UT    36260                   0.1059
# 178       Las Vegas, NV    29820                   0.1100
# 362           Provo, UT    39340                   0.2001
# 182      Greenville, SC    24860                   0.0979
# 202         Phoenix, AZ    38060                   0.1195
#
#      1-Year Household Growth   Population  5-Year Population Growth  \
# 344                   0.0211 1254675.0000                    0.0723
# 360                   0.0334  771602.0000                    0.1392
# 298                   0.0202 1316145.0000                    0.0552
# 114                   0.0266  803398.0000                    0.0796
# 314                   0.0168  593318.0000                    0.0501
# 350                   0.0221  638359.0000                    0.0818
# 178                   0.0197 2265926.0000                    0.0727
# 362                   0.0431  677964.0000                    0.1546
# 182                   0.0215  931405.0000                    0.0676
# 202                   0.0221 4864209.0000                    0.0665
#
#      1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 344                    0.0080        0.0535              547500.0000
# 360                    0.0279        0.0455              471700.0000
# 298                    0.0099        0.0661              357600.0000
# 114                    0.0170        0.1206              384800.0000
# 314                    0.0101        0.0612              259700.0000
# 350                    0.0127        0.0501              487400.0000
# 178                    0.0156        0.0985              437900.0000
# 362                    0.0274        0.0423              566900.0000
# 182                    0.0144        0.0968              281800.0000
# 202                    0.0160        0.0901              457400.0000
#
#      5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 344               0.6631               1491.0000              0.4632
# 360               0.7840               1379.0000              0.6320
# 298               0.4531               1303.0000              0.3996
# 114               0.5216               1505.0000              0.5095
# 314               0.3770                969.0000              0.2344
# 350               0.7235               1364.0000              0.5660
# 178               0.5279               1450.0000              0.4872
# 362               0.7174               1415.0000              0.5150
# 182               0.6665                984.0000              0.4471
# 202               0.7131               1605.0000              0.6806
#
#      ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 344                       0.2723  454070.0000
# 360                       0.2923  298787.0000
# 298                       0.3644  553455.0000
# 114                       0.3911  362156.0000
# 314                       0.3731  255664.0000
# 350                       0.2799  216503.0000
# 178                       0.3311  923275.0000
# 362                       0.2496  199201.0000
# 182                       0.3492  406036.0000
# 202                       0.3509 1996937.0000
#
#                            msa_name_original  Population_Size_Category  \
# 344                Salt Lake City-Murray, UT                         5
# 360                           Boise City, ID                         4
# 298                             Richmond, VA                         5
# 114          Charleston-North Charleston, SC                         4
# 314                  Harrisburg-Carlisle, PA                         4
# 350                                Ogden, UT                         4
# 178  Las Vegas-Henderson-North Las Vegas, NV                         5
# 362                      Provo-Orem-Lehi, UT                         4
# 182            Greenville-Anderson-Greer, SC                         4
# 202                Phoenix-Mesa-Chandler, AZ                         5
#
#     msa_code_bls         Jobs  5-Year Job Growth     Income  \
# 344        41620  844000.0000             0.1189 67193.8800
# 360        14260  409400.0000             0.1768 56797.5200
# 298        40060  729000.0000             0.0611 57579.0800
# 114        16700  433600.0000             0.1429 58421.4800
# 314        25420  368700.0000             0.0392 58116.7600
# 350        36260  303700.0000             0.1256 51878.3200
# 178        29820 1156000.0000             0.1158 53550.6400
# 362        39340  312400.0000             0.1644 55432.0000
# 182        24860  467700.0000             0.0831 58715.2800
# 202        38060 2444300.0000             0.1212 63516.9600
#
#      5-Year Income Growth  Unemployment_Rate  permit_data_for_year  \
# 344                0.2873             3.8000             2023.0000
# 360                0.3753             3.6000             2023.0000
# 298                0.2395             3.6000             2023.0000
# 114                0.2334             4.6000             2023.0000
# 314                0.1988             3.8000             2023.0000
# 350                0.1879             3.7000             2023.0000
# 178                0.2539             6.1000             2023.0000
# 362                0.0785             4.0000             2023.0000
# 182                0.2919             5.1000             2023.0000
# 202                0.2263             3.5000             2023.0000
#
#      sfh_permits  duplex_unit_permits  small_multifamily_unit_permits  \
# 344    3163.0000              96.0000                        390.0000
# 360    6508.0000              38.0000                        268.0000
# 298    4590.0000             224.0000                        232.0000
# 114    6184.0000              82.0000                        316.0000
# 314    1213.0000              20.0000                         70.0000
# 350    1871.0000               2.0000                        158.0000
# 178   10087.0000              40.0000                        250.0000
# 362    4663.0000              38.0000                        172.0000
# 182    6685.0000             396.0000                        536.0000
# 202   24708.0000            1730.0000                       1872.0000
#
#      commercial_multifamily_unit_permits  total_unit_permits  percent_sfh  \
# 344                            5682.0000           9235.0000      34.2501
# 360                            3115.0000           9891.0000      65.7972
# 298                            5151.0000           9973.0000      46.0243
# 114                            2073.0000           8573.0000      72.1334
# 314                             581.0000           1864.0000      65.0751
# 350                            1371.0000           3400.0000      55.0294
# 178                            2736.0000          13073.0000      77.1590
# 362                            1346.0000           6181.0000      75.4409
# 182                             463.0000           7684.0000      86.9990
# 202                           19036.0000          45616.0000      54.1652
#
#      percent_duplex  percent_small_multi  percent_large_multi  \
# 344          1.0395               4.2231              61.5268
# 360          0.3842               2.7095              31.4933
# 298          2.2461               2.3263              51.6495
# 114          0.9565               3.6860              24.1806
# 314          1.0730               3.7554              31.1695
# 350          0.0588               4.6471              40.3235
# 178          0.3060               1.9123              20.9286
# 362          0.6148               2.7827              21.7764
# 182          5.1536               6.9755               6.0255
# 202          3.7925               4.1038              41.7310
#
#      Permits_as_Percent_of_Total_Units  housecanary_median_price  \
# 344                             0.0203               600000.0000
# 360                             0.0331               492495.0000
# 298                             0.0180               399975.0000
# 114                             0.0237               423190.0000
# 314                             0.0073               247500.0000
# 350                             0.0157                       NaN
# 178                             0.0142               485000.0000
# 362                             0.0310                       NaN
# 182                             0.0189               333250.0000
# 202                             0.0228               475000.0000
#
#      housecanary_median_rent  housecanary_rentpriceratio  \
# 344                2815.0000                      0.4692
# 360                2612.0000                      0.5304
# 298                2395.0000                      0.5988
# 114                2800.0000                      0.6616
# 314                1995.0000                      0.8061
# 350                      NaN                         NaN
# 178                2300.0000                      0.4742
# 362                      NaN                         NaN
# 182                1895.0000                      0.5686
# 202                2475.0000                      0.5211
#
#      1-Year Price Forecast  1-Year Rent Forecast state  \
# 344                 0.0469                   NaN    UT
# 360                 0.0560               -0.0039    ID
# 298                 0.0641                0.0297    VA
# 114                 0.0537                0.0500    SC
# 314                 0.0567                0.0370    PA
# 350                 0.0544                   NaN    UT
# 178                 0.0306                0.0288    NV
# 362                 0.0287                   NaN    UT
# 182                 0.0551                0.0318    SC
# 202                 0.0227                0.0145    AZ
#
#                metro_or_micro_area  median_prop_taxes_by_msa  insurance  \
# 344  Metropolitan Statistical Area                 2365.0000  2161.0000
# 360  Metropolitan Statistical Area                 2229.0000  2449.0000
# 298  Metropolitan Statistical Area                 2500.0000  2694.0000
# 114  Metropolitan Statistical Area                 1573.0000  3219.0000
# 314  Metropolitan Statistical Area                 2958.0000  2130.0000
# 350  Metropolitan Statistical Area                 2115.0000  2161.0000
# 178  Metropolitan Statistical Area                 1752.0000  1853.0000
# 362  Metropolitan Statistical Area                 1817.0000  2161.0000
# 182  Metropolitan Statistical Area                 1305.0000  3219.0000
# 202  Metropolitan Statistical Area                 1734.0000  3063.0000
#
#      1-Year_HH_Growth_Minus_Percent_New_Supply  RANK_5-Year Household Growth  \
# 344                                     0.0007                           332
# 360                                     0.0003                           356
# 298                                     0.0021                           299
# 114                                     0.0030                           341
# 314                                     0.0095                           214
# 350                                     0.0064                           311
# 178                                     0.0055                           318
# 362                                     0.0120                           365
# 182                                     0.0025                           301
# 202                                    -0.0007                           329
#
#      RANK_5-Year Population Growth  RANK_5-Year Job Growth  RANK_Income  \
# 344                            304                     336          352
# 360                            361                     361          268
# 298                            268                     240          287
# 114                            317                     353          299
# 314                            258                     199          296
# 350                            321                     343          165
# 178                            307                     332          209
# 362                            365                     360          240
# 182                            299                     285          309
# 202                            296                     337          335
#
#      RANK_5-Year Income Growth  RANK_Unemployment_Rate  \
# 344                        284                     238
# 360                        337                     275
# 298                        239                     276
# 114                        226                     115
# 314                        180                     243
# 350                        171                     261
# 178                        253                      22
# 362                         63                     205
# 182                        287                      67
# 202                        216                     296
#
#      RANK_1-Year_HH_Growth_Minus_Percent_New_Supply  \
# 344                                             129
# 360                                             123
# 298                                             164
# 114                                             188
# 314                                             317
# 350                                             266
# 178                                             251
# 362                                             336
# 182                                             175
# 202                                              99
#
#      RANK_ACS_1_Year_Rent-Price_Ratio  RANK_1-Year Price Forecast  \
# 344                                42                         233
# 360                                69                         288
# 298                               213                         326
# 114                               265                         277
# 314                               231                         293
# 350                                52                         279
# 178                               134                         113
# 362                                28                          94
# 182                               176                         285
# 202                               180                          57
#
#      RANK_insurance  RANK_median_prop_taxes_by_msa  RANK_Vacancy_Rate  \
# 344             277                            175                345
# 360             246                            190                361
# 298             221                            160                299
# 114             176                            269                115
# 314             288                            119                315
# 350             275                            197                351
# 178             332                            245                179
# 362             276                            237                363
# 182             178                            301                183
# 202             185                            251                203
#
#      Total_Rank_Sum
# 344            7016
# 360            7007
# 298            6986
# 114            6946
# 314            6848
# 350            6787
# 178            6783
# 362            6767
# 182            6678
# 202            6634

# %%
usa_msa[usa_msa['msa_name'].str.contains("Fayetteville")]
# Out:
#             msa_name msa_code  5-Year Household Growth  \
# 18  Fayetteville, AR    22220                   0.1247
# 87  Fayetteville, NC    22180                   0.0236
#
#     1-Year Household Growth  Population  5-Year Population Growth  \
# 18                   0.0287 550596.0000                    0.1204
# 87                   0.0165 387819.0000                    0.0064
#
#     1-Year Population Growth  Vacancy_Rate  ACS_1_Year_Median_Price  \
# 18                    0.0233        0.0845              342100.0000
# 87                    0.0054        0.1092              216900.0000
#
#     5-Year Price Growth  ACS_1_Year_Median_Rent  5-Year Rent Growth  \
# 18               0.9706               1001.0000              0.4918
# 87               0.5638               1028.0000              0.4398
#
#     ACS_1_Year_Rent-Price_Ratio  Total_Units  \
# 18                       0.2926  223045.0000
# 87                       0.4740  163024.0000
#
#                      msa_name_original  Population_Size_Category msa_code_bls  \
# 18  Fayetteville-Springdale-Rogers, AR                         4        22220
# 87                    Fayetteville, NC                         3        22180
#
#           Jobs  5-Year Job Growth     Income  5-Year Income Growth  \
# 18 312800.0000             0.1620 56077.8400                0.3701
# 87 136400.0000             0.0476 42458.5200                0.3146
#
#     Unemployment_Rate  permit_data_for_year  sfh_permits  duplex_unit_permits  \
# 18             2.6000             2023.0000    5349.0000             428.0000
# 87             5.7000             2023.0000    2542.0000               4.0000
#
#     small_multifamily_unit_permits  commercial_multifamily_unit_permits  \
# 18                        511.0000                            1055.0000
# 87                          4.0000                              30.0000
#
#     total_unit_permits  percent_sfh  percent_duplex  percent_small_multi  \
# 18           6915.0000      77.3536          6.1894               7.3897
# 87           2576.0000      98.6801          0.1553               0.1553
#
#     percent_large_multi  Permits_as_Percent_of_Total_Units  \
# 18              15.2567                             0.0310
# 87               1.1646                             0.0158
#
#     housecanary_median_price  housecanary_median_rent  \
# 18               338745.0000                1995.0000
# 87               301750.0000                1800.0000
#
#     housecanary_rentpriceratio  1-Year Price Forecast  1-Year Rent Forecast  \
# 18                      0.5889                 0.0379                0.0295
# 87                      0.5965                 0.0315               -0.0100
#
#    state            metro_or_micro_area  median_prop_taxes_by_msa  insurance  \
# 18    AR  Metropolitan Statistical Area                 1442.0000  4675.0000
# 87    NC  Metropolitan Statistical Area                 1665.0000  3398.0000
#
#     1-Year_HH_Growth_Minus_Percent_New_Supply
# 18                                    -0.0023
# 87                                     0.0007
